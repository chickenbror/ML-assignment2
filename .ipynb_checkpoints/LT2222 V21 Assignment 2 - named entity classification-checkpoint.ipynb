# %% [markdown]
# ## Introduction
#
# In this assignment, you are going to build a classifier for named entities from the Groningen Meaning Bank corpus.  Named entity recognition (NER) takes noun phrases from a text and identifies whether they are persons, organizations, and so on.  You will be using the Groningen Meaning Bank named entity corpus available on mltgpu at `/scratch/lt2222-v21-resources/GMB_dataset.txt`.  In this version of the task, you will assume we know *that* something is a named entity, and instead use multi-class classification to identify its type.  So you will be doing named entity classification but *not* recognition.
#
# The data looks like this:
#
# ```
# 3996    182.0   Nicole  NNP     B-per
# 3997    182.0   Ritchie NNP     I-per
# 3998    182.0   is      VBZ     O
# 3999    182.0   pregnant        JJ      O
# 4000    182.0   .       .       O
# 4001    183.0   Speaking        VBG     O
# 4002    183.0   to      TO      O
# 4003    183.0   ABC     NNP     B-org
# 4004    183.0   News    NNP     I-org
# 4005    183.0   interviewer     NN      O
# 4006    183.0   Dianne  NNP     B-per
# 4007    183.0   Sawyer  NNP     I-per
# 4008    183.0   ,       ,       O
# 4009    183.0   the     DT      O
# 4010    183.0   25-year-old     JJ      O
# 4011    183.0   co-star NN      O
# 4012    183.0   of      IN      O
# 4013    183.0   TV      NN      O
# 4014    183.0   's      POS     O
# 4015    183.0   The     DT      B-art
# 4016    183.0   Simple  NNP     I-art
# 4017    183.0   Life    NNP     I-art
# 4018    183.0   said    VBD     O
# 4019    183.0   she     PRP     O
# 4020    183.0   is      VBZ     O
# 4021    183.0   almost  RB      O
# 4022    183.0   four    CD      O
# 4023    183.0   months  NNS     O
# 4024    183.0   along   IN      O
# 4025    183.0   in      IN      O
# 4026    183.0   her     PRP$    O
# 4027    183.0   pregnancy       NN      O
# 4028    183.0   .       .       O
# ```
#
# The first column is the line number.  The second column is a sentence number (for some reason given as a float; ignore it).  The third column is the word.  The fourth column is a part of speech (POS) tag in Penn Treebank format.  The last column contains the named entity annotation.
#
# The annotation works like this.  Every `O` just means that the row does not represent a named entity.  `B-xyx` means the first word in a named entity with type `xyx`. `I-xyz` means the second and later words of an `xyz` entity, if there are any.  That means that every time there's a `B` or an `I`, there's a named entity.
#
# The entity types in the corpus are `art`,
# `eve`,
# `geo`,
# `gpe`,
# `nat`,
# `org`,
# `per`,
# and `tim`
#
# Your task is the following.
# 1. To preprocess the text (lowercase and lemmatize; punctuation can be preserved as it gets its own rows).
# 2. To create instances from every from every identified named entity in the text with the type of the NE as the class, and a surrounding context of five words on either side as the features.
# 3. To generate vectors and split the instances into training and testing datasets at random.
# 4. To train a support vector machine (via `sklearn.svm.LinearSVC`) for classifying the NERs.
# 5. To evaluate the performance of the classifier.
#
# You will do this by modifying a separate file containing functions that will be called from this notebook as a module.  You can modify this notebook for testing purposes but please only submit the original.  You will document everything in Markdown in README.md and submit a GitHub repository URL.
#
# This assignment is due on **Tuesday, 2021 March 9 at 23:59**.  It has **25 points** and **7 bonus points**.

# %%
import a2
from sklearn.svm import LinearSVC

# %%
gmbfile = open('GMB_dataset.txt', "r")

# %% [markdown]
# ## Part 1 - preprocessing (3 points)

# %% [markdown]
# See step 1 above.  The data is coming to you as an unused file handle object.  You can return the data in any indexable form you like.  You can also choose to remove infrequent or uninformative words to reduce the size of the feature space. (Document this in README.md.)

# %%
inputdata = a2.preprocess(gmbfile)
gmbfile.close()
inputdata[20:40]
# Out:
#     sentenceNr       word  POS NEtag
# 20           1       from   IN     O
# 21           1       that   DT     O
# 22           1    country   NN     O
# 23           1          .    .     O
# 24           2     family  NNS     O
# 25           2         of   IN     O
# 26           2    soldier  NNS     O
# 27           2     killed  VBN     O
# 28           2         in   IN     O
# 29           2        the   DT     O
# 30           2   conflict   NN     O
# 31           2     joined  VBD     O
# 32           2        the   DT     O
# 33           2  protester  NNS     O
# 34           2        who   WP     O
# 35           2    carried  VBD     O
# 36           2     banner  NNS     O
# 37           2       with   IN     O
# 38           2       such   JJ     O
# 39           2     slogan  NNS     O

# %% [markdown]
# ## Part 2 - Creating instances (7 points)

# %% [markdown]
# Do step 2 above.  You will create a collection of Instance objects.  Remember to consider the case where the NE is at the beginning of a sentence or at the end, or close to either (you can create a special start token for that).  You can also start counting from before the `B` end of the NE mention and after the last `I` of the NE mention. That means that the instances should include things before and after the named entity mention, but not the named entity text itself.

# %%
words_only = inputdata.groupby('sentenceNr')['word'].apply(list)
tags_only = inputdata.groupby('sentenceNr')['NEtag'].apply(list)
sents_words_tags = list(zip(words_only, tags_only))
sentences = []
for sen in sents_words_tags:
    sentences.append( list(zip(sen[0],sen[1])) )
sentences # 2999 sublists, each = [(w1,tag),(w2,tag)...]
# Out:
# [[('thousand', 'O'),
#   ('of', 'O'),
#   ('demonstrator', 'O'),
#   ('have', 'O'),
#   ('marched', 'O'),
#   ('through', 'O'),
#   ('london', 'B-geo'),
#   ('to', 'O'),
#   ('protest', 'O'),
#   ('the', 'O'),
#   ('war', 'O'),
#   ('in', 'O'),
#   ('iraq', 'B-geo'),
#   ('and', 'O'),
#   ('demand', 'O'),
#   ('the', 'O'),
#   ('withdrawal', 'O'),
#   ('of', 'O'),
#   ('british', 'B-gpe'),
#   ('troop', 'O'),
#   ('from', 'O'),
#   ('that', 'O'),
#   ('country', 'O'),
#   ('.', 'O')],
#  [('family', 'O'),
#   ('of', 'O'),
#   ('soldier', 'O'),
#   ('killed', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('conflict', 'O'),
#   ('joined', 'O'),
#   ('the', 'O'),
#   ('protester', 'O'),
#   ('who', 'O'),
#   ('carried', 'O'),
#   ('banner', 'O'),
#   ('with', 'O'),
#   ('such', 'O'),
#   ('slogan', 'O'),
#   ('a', 'O'),
#   ('""""', 'O'),
#   ('bush', 'B-per'),
#   ('number', 'O'),
#   ('one', 'O'),
#   ('terrorist', 'O'),
#   ('""""', 'O'),
#   ('and', 'O'),
#   ('""""', 'O'),
#   ('stop', 'O'),
#   ('the', 'O'),
#   ('bombing', 'O'),
#   ('.', 'O'),
#   ('""""', 'O')],
#  [('they', 'O'),
#   ('marched', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('house', 'O'),
#   ('of', 'O'),
#   ('parliament', 'O'),
#   ('to', 'O'),
#   ('a', 'O'),
#   ('rally', 'O'),
#   ('in', 'O'),
#   ('hyde', 'B-geo'),
#   ('park', 'I-geo'),
#   ('.', 'O')],
#  [('police', 'O'),
#   ('put', 'O'),
#   ('the', 'O'),
#   ('number', 'O'),
#   ('of', 'O'),
#   ('marcher', 'O'),
#   ('at', 'O'),
#   ('10,000', 'O'),
#   ('while', 'O'),
#   ('organizer', 'O'),
#   ('claimed', 'O'),
#   ('it', 'O'),
#   ('wa', 'O'),
#   ('1,00,000', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('protest', 'O'),
#   ('come', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('eve', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('annual', 'O'),
#   ('conference', 'O'),
#   ('of', 'O'),
#   ('britain', 'B-geo'),
#   ("'s", 'O'),
#   ('ruling', 'O'),
#   ('labor', 'B-org'),
#   ('party', 'I-org'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('southern', 'O'),
#   ('english', 'B-gpe'),
#   ('seaside', 'O'),
#   ('resort', 'O'),
#   ('of', 'O'),
#   ('brighton', 'B-geo'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('party', 'O'),
#   ('is', 'O'),
#   ('divided', 'O'),
#   ('over', 'O'),
#   ('britain', 'B-gpe'),
#   ("'s", 'O'),
#   ('participation', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('iraq', 'B-geo'),
#   ('conflict', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('continued', 'O'),
#   ('deployment', 'O'),
#   ('of', 'O'),
#   ('8,500', 'O'),
#   ('british', 'B-gpe'),
#   ('troop', 'O'),
#   ('in', 'O'),
#   ('that', 'O'),
#   ('country', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('london', 'B-geo'),
#   ('march', 'O'),
#   ('came', 'O'),
#   ('ahead', 'O'),
#   ('of', 'O'),
#   ('anti-war', 'O'),
#   ('protest', 'O'),
#   ('today', 'O'),
#   ('in', 'O'),
#   ('other', 'O'),
#   ('city', 'O'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('rome', 'B-geo'),
#   (',', 'O'),
#   ('paris', 'B-geo'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('madrid', 'B-geo'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('international', 'B-org'),
#   ('atomic', 'I-org'),
#   ('energy', 'I-org'),
#   ('agency', 'I-org'),
#   ('is', 'O'),
#   ('to', 'O'),
#   ('hold', 'O'),
#   ('second', 'O'),
#   ('day', 'O'),
#   ('of', 'O'),
#   ('talk', 'O'),
#   ('in', 'O'),
#   ('vienna', 'B-geo'),
#   ('wednesday', 'B-tim'),
#   ('on', 'O'),
#   ('how', 'O'),
#   ('to', 'O'),
#   ('respond', 'O'),
#   ('to', 'O'),
#   ('iran', 'B-gpe'),
#   ("'s", 'O'),
#   ('resumption', 'O'),
#   ('of', 'O'),
#   ('low-level', 'O'),
#   ('uranium', 'O'),
#   ('conversion', 'O'),
#   ('.', 'O')],
#  [('iran', 'B-gpe'),
#   ('this', 'O'),
#   ('week', 'O'),
#   ('restarted', 'O'),
#   ('part', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('conversion', 'O'),
#   ('process', 'O'),
#   ('at', 'O'),
#   ('it', 'O'),
#   ('isfahan', 'B-geo'),
#   ('nuclear', 'O'),
#   ('plant', 'O'),
#   ('.', 'O')],
#  [('iranian', 'B-gpe'),
#   ('official', 'O'),
#   ('say', 'O'),
#   ('they', 'O'),
#   ('expect', 'O'),
#   ('to', 'O'),
#   ('get', 'O'),
#   ('access', 'O'),
#   ('to', 'O'),
#   ('sealed', 'O'),
#   ('sensitive', 'O'),
#   ('part', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('plant', 'O'),
#   ('wednesday', 'B-tim'),
#   (',', 'O'),
#   ('after', 'O'),
#   ('an', 'O'),
#   ('iaea', 'B-org'),
#   ('surveillance', 'O'),
#   ('system', 'O'),
#   ('begin', 'O'),
#   ('functioning', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('step', 'O'),
#   ('will', 'O'),
#   ('allow', 'O'),
#   ('the', 'O'),
#   ('facility', 'O'),
#   ('to', 'O'),
#   ('operate', 'O'),
#   ('at', 'O'),
#   ('full', 'O'),
#   ('capacity', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('european', 'B-org'),
#   ('union', 'I-org'),
#   (',', 'O'),
#   ('with', 'O'),
#   ('u.s.', 'B-gpe'),
#   ('backing', 'O'),
#   (',', 'O'),
#   ('ha', 'O'),
#   ('threatened', 'O'),
#   ('to', 'O'),
#   ('refer', 'O'),
#   ('iran', 'B-gpe'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('u.n.', 'B-org'),
#   ('security', 'I-org'),
#   ('council', 'I-org'),
#   (',', 'O'),
#   ('which', 'O'),
#   ('could', 'O'),
#   ('impose', 'O'),
#   ('sanction', 'O'),
#   ('if', 'O'),
#   ('it', 'O'),
#   ('find', 'O'),
#   ('tehran', 'B-gpe'),
#   ('ha', 'O'),
#   ('violated', 'O'),
#   ('the', 'O'),
#   ('nuclear', 'B-art'),
#   ('non-proliferation', 'I-art'),
#   ('treaty', 'O'),
#   ('.', 'O')],
#  [('iran', 'B-gpe'),
#   ("'s", 'O'),
#   ('new', 'O'),
#   ('president', 'B-per'),
#   ('mahmoud', 'I-per'),
#   ('ahmadinejad', 'I-per'),
#   ('said', 'O'),
#   ('tuesday', 'B-tim'),
#   ('that', 'O'),
#   ('european', 'B-gpe'),
#   ('incentive', 'O'),
#   ('aimed', 'O'),
#   ('at', 'O'),
#   ('persuading', 'O'),
#   ('iran', 'B-gpe'),
#   ('to', 'O'),
#   ('end', 'O'),
#   ('it', 'O'),
#   ('nuclear', 'O'),
#   ('fuel', 'O'),
#   ('program', 'O'),
#   ('are', 'O'),
#   ('an', 'O'),
#   ('insult', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('iranian', 'B-gpe'),
#   ('nation', 'O'),
#   ('.', 'O')],
#  [('two', 'O'),
#   ('german', 'B-gpe'),
#   ('and', 'O'),
#   ('four', 'O'),
#   ('nigerian', 'B-gpe'),
#   ('oil', 'O'),
#   ('worker', 'O'),
#   ('were', 'O'),
#   ('kidnapped', 'O'),
#   ('by', 'O'),
#   ('armed', 'O'),
#   ('militant', 'O'),
#   ('during', 'O'),
#   ('a', 'O'),
#   ('raid', 'O'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('boat', 'O'),
#   ('in', 'O'),
#   ('nigeria', 'B-geo'),
#   ("'s", 'O'),
#   ('southern', 'O'),
#   ('oil-rich', 'O'),
#   ('delta', 'B-geo'),
#   ('region', 'O'),
#   ('.', 'O')],
#  [('an', 'O'),
#   ('official', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('german', 'B-gpe'),
#   ('firm', 'O'),
#   ('bilfinger', 'B-org'),
#   ('berger', 'I-org'),
#   (',', 'O'),
#   ('thomas', 'B-per'),
#   ('horbach', 'I-per'),
#   (',', 'O'),
#   ('said', 'O'),
#   ('the', 'O'),
#   ('gunman', 'O'),
#   ('stopped', 'O'),
#   ('the', 'O'),
#   ('supply', 'O'),
#   ('boat', 'O'),
#   ('wednesday', 'B-tim'),
#   ('a', 'O'),
#   ('it', 'O'),
#   ('sailed', 'O'),
#   ('from', 'O'),
#   ('delta', 'B-geo'),
#   ('state', 'I-geo'),
#   ('to', 'O'),
#   ('bayelsa', 'B-geo'),
#   ('state', 'I-geo'),
#   ('to', 'O'),
#   ('inspect', 'O'),
#   ('an', 'O'),
#   ('offshore', 'O'),
#   ('oil', 'O'),
#   ('field', 'O'),
#   ('owned', 'O'),
#   ('by', 'O'),
#   ('royal-dutch', 'B-org'),
#   ('shell', 'I-org'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('german', 'B-gpe'),
#   ('firm', 'O'),
#   ('work', 'O'),
#   ('a', 'O'),
#   ('a', 'O'),
#   ('sub-contractor', 'O'),
#   ('for', 'O'),
#   ('shell', 'B-org'),
#   ('.', 'O')],
#  [('militant', 'O'),
#   ('group', 'O'),
#   ('frequently', 'O'),
#   ('attack', 'O'),
#   ('oil', 'O'),
#   ('operation', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('niger', 'B-geo'),
#   ('delta', 'I-geo'),
#   ('to', 'O'),
#   ('demand', 'O'),
#   ('social', 'O'),
#   ('service', 'O'),
#   ('and', 'O'),
#   ('better', 'O'),
#   ('job', 'O'),
#   ('opportunity', 'O'),
#   ('from', 'O'),
#   ('multinational', 'O'),
#   ('company', 'O'),
#   ('.', 'O')],
#  [('poor', 'O'),
#   ('resident', 'O'),
#   ('often', 'O'),
#   ('complain', 'O'),
#   ('they', 'O'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('cheated', 'O'),
#   ('out', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('huge', 'O'),
#   ('rich', 'O'),
#   ('extracted', 'O'),
#   ('from', 'O'),
#   ('their', 'O'),
#   ('tribal', 'O'),
#   ('land', 'O'),
#   ('-', 'O'),
#   ('where', 'O'),
#   ('the', 'O'),
#   ('bulk', 'O'),
#   ('of', 'O'),
#   ('nigeria', 'B-gpe'),
#   ("'s", 'O'),
#   ('2.3', 'O'),
#   ('million', 'O'),
#   ('barrel', 'O'),
#   ('of', 'O'),
#   ('petroleum', 'O'),
#   ('are', 'O'),
#   ('pumped', 'O'),
#   ('daily', 'O'),
#   ('.', 'O')],
#  [('suspected', 'O'),
#   ('islamist', 'O'),
#   ('rebel', 'O'),
#   ('have', 'O'),
#   ('fired', 'O'),
#   ('mortar', 'O'),
#   ('shell', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('palace', 'O'),
#   ('used', 'O'),
#   ('by', 'O'),
#   ('somalia', 'B-geo'),
#   ("'s", 'O'),
#   ('interim', 'O'),
#   ('president', 'B-per'),
#   ('abdullahi', 'I-per'),
#   ('yusuf', 'I-per'),
#   ('ahmad', 'I-per'),
#   ('.', 'O')],
#  [('it', 'O'),
#   ('wa', 'O'),
#   ('not', 'O'),
#   ('immediately', 'O'),
#   ('clear', 'O'),
#   ('if', 'O'),
#   ('the', 'O'),
#   ('president', 'O'),
#   ('wa', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('palace', 'O'),
#   ('in', 'O'),
#   ('mogadishu', 'B-geo'),
#   ('when', 'O'),
#   ('the', 'O'),
#   ('attack', 'O'),
#   ('occurred', 'O'),
#   ('or', 'O'),
#   ('if', 'O'),
#   ('anyone', 'O'),
#   ('wa', 'O'),
#   ('hurt', 'O'),
#   ('.', 'O')],
#  [('local', 'O'),
#   ('news', 'O'),
#   ('report', 'O'),
#   ('said', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('five', 'O'),
#   ('mortar', 'O'),
#   ('shell', 'O'),
#   ('hit', 'O'),
#   ('the', 'O'),
#   ('palace', 'O'),
#   ('compound', 'O'),
#   ('and', 'O'),
#   ('other', 'O'),
#   ('mortar', 'O'),
#   ('were', 'O'),
#   ('fired', 'O'),
#   ('elsewhere', 'O'),
#   ('in', 'O'),
#   ('mogadishu', 'B-geo'),
#   ('wednesday', 'B-tim'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('attack', 'O'),
#   ('occurred', 'O'),
#   ('after', 'O'),
#   ('the', 'O'),
#   ('government', 'O'),
#   ('said', 'O'),
#   ('it', 'O'),
#   ('will', 'O'),
#   ('go', 'O'),
#   ('ahead', 'O'),
#   ('with', 'O'),
#   ('a', 'O'),
#   ('reconciliation', 'O'),
#   ('conference', 'O'),
#   ('to', 'O'),
#   ('which', 'O'),
#   ('more', 'O'),
#   ('than', 'O'),
#   ('1,300', 'O'),
#   ('somali', 'B-gpe'),
#   ('elder', 'O'),
#   (',', 'O'),
#   ('warlord', 'O'),
#   ('and', 'O'),
#   ('politician', 'O'),
#   ('are', 'O'),
#   ('invited', 'O'),
#   ('.', 'O')],
#  [('iraqi', 'B-gpe'),
#   ('military', 'O'),
#   ('official', 'O'),
#   ('say', 'O'),
#   ('tank', 'O'),
#   ('and', 'O'),
#   ('troop', 'O'),
#   ('have', 'O'),
#   ('arrived', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('northern', 'O'),
#   ('city', 'O'),
#   ('mosul', 'B-geo'),
#   ('for', 'O'),
#   ('a', 'O'),
#   ('new', 'O'),
#   ('offensive', 'O'),
#   ('against', 'O'),
#   ('al', 'B-org'),
#   ('qaida', 'I-org'),
#   ('in', 'I-org'),
#   ('iraq', 'I-org'),
#   ('fighter', 'O'),
#   ('.', 'O')],
#  [('official', 'O'),
#   ('will', 'O'),
#   ('not', 'O'),
#   ('say', 'O'),
#   ('how', 'O'),
#   ('many', 'O'),
#   ('troop', 'O'),
#   ('have', 'O'),
#   ('arrived', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('sunni', 'B-geo'),
#   ('arab', 'I-geo'),
#   ('and', 'O'),
#   ('kurdish', 'B-geo'),
#   ('city', 'O'),
#   (',', 'O'),
#   ('where', 'O'),
#   ('bombing', 'O'),
#   ('last', 'O'),
#   ('week', 'O'),
#   ('killed', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('34', 'O'),
#   ('people', 'O'),
#   ('and', 'O'),
#   ('wounded', 'O'),
#   ('more', 'O'),
#   ('than', 'O'),
#   ('200', 'O'),
#   ('.', 'O')],
#  [('u.s.', 'B-gpe'),
#   ('commander', 'O'),
#   ('have', 'O'),
#   ('not', 'O'),
#   ('explained', 'O'),
#   ('how', 'O'),
#   ('american', 'B-gpe'),
#   ('force', 'O'),
#   ('will', 'O'),
#   ('participate', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('offensive', 'O'),
#   ('.', 'O')],
#  [('official', 'O'),
#   ('say', 'O'),
#   ('al', 'B-org'),
#   ('qaida', 'I-org'),
#   ('in', 'I-org'),
#   ('iraq', 'I-org'),
#   ('fighter', 'O'),
#   ('have', 'O'),
#   ('fled', 'O'),
#   ('successful', 'O'),
#   ('campaign', 'O'),
#   ('against', 'O'),
#   ('them', 'O'),
#   ('in', 'O'),
#   ('anbar', 'B-geo'),
#   ('province', 'O'),
#   ('and', 'O'),
#   ('baghdad', 'B-geo'),
#   ('to', 'O'),
#   ('other', 'O'),
#   ('northern', 'O'),
#   ('province', 'O'),
#   ('.', 'O')],
#  [('mosul', 'B-geo'),
#   ('is', 'O'),
#   ('the', 'O'),
#   ('largest', 'O'),
#   ('city', 'O'),
#   ('north', 'O'),
#   ('of', 'O'),
#   ('baghdad', 'B-geo'),
#   ('and', 'O'),
#   ('ha', 'O'),
#   ('long', 'O'),
#   ('been', 'O'),
#   ('a', 'O'),
#   ('stronghold', 'O'),
#   ('of', 'O'),
#   ('sunni', 'B-org'),
#   ('militant', 'O'),
#   ('fighter', 'O'),
#   ('.', 'O')],
#  [('in', 'O'),
#   ('other', 'O'),
#   ('violence', 'O'),
#   (',', 'O'),
#   ('u.s.', 'B-gpe'),
#   ('official', 'O'),
#   ('said', 'O'),
#   ('one', 'O'),
#   ('american', 'B-gpe'),
#   ('soldier', 'O'),
#   ('wa', 'O'),
#   ('killed', 'O'),
#   ('while', 'O'),
#   ('on', 'O'),
#   ('patrol', 'O'),
#   ('in', 'O'),
#   ('baghdad', 'B-geo'),
#   ('sunday', 'B-tim'),
#   ('.', 'O')],
#  [('egyptian', 'B-gpe'),
#   ('police', 'O'),
#   ('have', 'O'),
#   ('arrested', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('16', 'O'),
#   ('member', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('opposition', 'O'),
#   ('muslim', 'B-org'),
#   ('brotherhood', 'I-org'),
#   ('a', 'O'),
#   ('part', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('country', 'O'),
#   ('prepare', 'O'),
#   ('for', 'O'),
#   ('parliamentary', 'O'),
#   ('runoff', 'O'),
#   ('election', 'O'),
#   ('saturday', 'B-tim'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('arrest', 'O'),
#   ('occurred', 'O'),
#   ('friday', 'B-tim'),
#   ('in', 'O'),
#   ('alexandria', 'B-geo'),
#   ('.', 'O')],
#  [('a', 'O'),
#   ('spokesman', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('brotherhood', 'B-org'),
#   ('said', 'O'),
#   ('the', 'O'),
#   ('arrest', 'O'),
#   ('are', 'O'),
#   ('an', 'O'),
#   ('attempt', 'O'),
#   ('to', 'O'),
#   ('cut', 'O'),
#   ('the', 'O'),
#   ('brotherhood', 'B-org'),
#   ('off', 'O'),
#   ('from', 'O'),
#   ('it', 'O'),
#   ('supporter', 'O'),
#   ('and', 'O'),
#   ('punishment', 'O'),
#   ('for', 'O'),
#   ('winning', 'O'),
#   ('parliamentary', 'O'),
#   ('seat', 'O'),
#   ('in', 'O'),
#   ('earlier', 'O'),
#   ('election', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('muslim', 'B-org'),
#   ('brotherhood', 'I-org'),
#   ('ha', 'O'),
#   ('tripled', 'O'),
#   ('it', 'O'),
#   ('strength', 'O'),
#   ('in', 'O'),
#   ('parliament', 'O'),
#   ('in', 'O'),
#   ('recent', 'O'),
#   ('election', 'O'),
#   (',', 'O'),
#   ('raising', 'O'),
#   ('the', 'O'),
#   ('party', 'O'),
#   ("'s", 'O'),
#   ('total', 'O'),
#   ('to', 'O'),
#   ('47', 'O'),
#   ('seat', 'O'),
#   ('.', 'O')],
#  [('in', 'O'),
#   ('saturday', 'B-tim'),
#   ("'s", 'O'),
#   ('election', 'O'),
#   (',', 'O'),
#   ('voter', 'O'),
#   ('will', 'O'),
#   ('cast', 'O'),
#   ('ballot', 'O'),
#   ('in', 'O'),
#   ('nine', 'O'),
#   ('province', 'O'),
#   ('where', 'O'),
#   ('no', 'O'),
#   ('candidate', 'O'),
#   ('won', 'O'),
#   ('a', 'O'),
#   ('majority', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('previous', 'O'),
#   ('round', 'O'),
#   ('of', 'O'),
#   ('voting', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('muslim', 'B-org'),
#   ('brotherhood', 'I-org'),
#   ('is', 'O'),
#   ('banned', 'O'),
#   ('a', 'O'),
#   ('a', 'O'),
#   ('political', 'O'),
#   ('party', 'O'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('it', 'O'),
#   ('endorses', 'O'),
#   ('so-called', 'O'),
#   ('independent', 'O'),
#   ('candidate', 'O'),
#   ('whose', 'O'),
#   ('allegiance', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('party', 'O'),
#   ('is', 'O'),
#   ('known', 'O'),
#   ('to', 'O'),
#   ('voter', 'O'),
#   ('.', 'O')],
#  [('hardline', 'O'),
#   ('lawmaker', 'O'),
#   ('in', 'O'),
#   ('pakistan', 'B-geo'),
#   ("'s", 'O'),
#   ('north', 'B-geo'),
#   ('west', 'I-geo'),
#   ('frontier', 'I-geo'),
#   ('province', 'I-geo'),
#   ('have', 'O'),
#   ('pushed', 'O'),
#   ('through', 'O'),
#   ('a', 'O'),
#   ('law', 'O'),
#   ('that', 'O'),
#   ('aim', 'O'),
#   ('to', 'O'),
#   ('ensure', 'O'),
#   ('""""', 'O'),
#   ('islamic', 'O'),
#   ('correctness', 'O'),
#   ('""""', 'O'),
#   ('in', 'O'),
#   ('public', 'O'),
#   ('place', 'O'),
#   ('and', 'O'),
#   ('establishes', 'O'),
#   ('a', 'O'),
#   ('morality', 'O'),
#   ('police', 'O'),
#   ('to', 'O'),
#   ('enforce', 'O'),
#   ('decent', 'O'),
#   ('behavior', 'O'),
#   ('.', 'O')],
#  [('a', 'O'),
#   ('six-party', 'O'),
#   ('coalition', 'O'),
#   ('of', 'O'),
#   ('religious', 'O'),
#   ('based', 'O'),
#   ('party', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('mutahida', 'B-org'),
#   ('majlis-e-amal', 'I-org'),
#   (',', 'O'),
#   ('dominates', 'O'),
#   ('the', 'O'),
#   ('provincial', 'O'),
#   ('assembly', 'O'),
#   (',', 'O'),
#   ('so', 'O'),
#   ('the', 'O'),
#   ('bill', 'O'),
#   ('wa', 'O'),
#   ('easily', 'O'),
#   ('passed', 'O'),
#   ('thursday', 'B-tim'),
#   ('by', 'O'),
#   ('a', 'O'),
#   ('vote', 'O'),
#   ('of', 'O'),
#   ('68-34', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('provincial', 'O'),
#   ('governor', 'O'),
#   ('must', 'O'),
#   ('still', 'O'),
#   ('sign', 'O'),
#   ('the', 'O'),
#   ('bill', 'O'),
#   ('before', 'O'),
#   ('it', 'O'),
#   ('becomes', 'O'),
#   ('law', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('step', 'O'),
#   ('seen', 'O'),
#   ('only', 'O'),
#   ('a', 'O'),
#   ('a', 'O'),
#   ('formality', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('proposed', 'O'),
#   ('law', 'O'),
#   ('call', 'O'),
#   ('for', 'O'),
#   ('setting', 'O'),
#   ('up', 'O'),
#   ('a', 'O'),
#   ('""""', 'O'),
#   ('religious', 'O'),
#   ('police', 'O'),
#   ('force', 'O'),
#   ('""""', 'O'),
#   ('to', 'O'),
#   ('make', 'O'),
#   ('sure', 'O'),
#   ('people', 'O'),
#   ('adhere', 'O'),
#   ('to', 'O'),
#   ('islamic', 'O'),
#   ('value', 'O'),
#   ('in', 'O'),
#   ('public', 'O'),
#   ('place', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('entertainment', 'O'),
#   ('outlet', 'O'),
#   ('close', 'O'),
#   ('during', 'O'),
#   ('weekly', 'O'),
#   ('friday', 'B-tim'),
#   ('prayer', 'O'),
#   ('.', 'O')],
#  [('violator', 'O'),
#   ('could', 'O'),
#   ('be', 'O'),
#   ('jailed', 'O'),
#   ('for', 'O'),
#   ('up', 'O'),
#   ('to', 'O'),
#   ('six', 'O'),
#   ('month', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('opposition', 'O'),
#   ('ha', 'O'),
#   ('denounced', 'O'),
#   ('the', 'O'),
#   ('measure', 'O'),
#   (',', 'O'),
#   ('comparing', 'O'),
#   ('it', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('draconian', 'O'),
#   ('rule', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('former', 'O'),
#   ('taleban', 'B-org'),
#   ('in', 'O'),
#   ('neighboring', 'O'),
#   ('afghanistan', 'B-geo'),
#   ('.', 'O')],
#  [('british', 'B-gpe'),
#   ('police', 'O'),
#   ('say', 'O'),
#   ('they', 'O'),
#   ('have', 'O'),
#   ('arrested', 'O'),
#   ('a', 'O'),
#   ('man', 'O'),
#   ('who', 'O'),
#   ('dressed', 'O'),
#   ('a', 'O'),
#   ('suicide', 'O'),
#   ('bomber', 'O'),
#   ('at', 'O'),
#   ('a', 'O'),
#   ('demonstration', 'O'),
#   ('against', 'O'),
#   ('the', 'O'),
#   ('publication', 'O'),
#   ('of', 'O'),
#   ('cartoon', 'O'),
#   ('depicting', 'O'),
#   ('islam', 'B-org'),
#   ("'s", 'O'),
#   ('prophet', 'B-per'),
#   ('muhammad', 'I-per'),
#   ('.', 'O')],
#  [('bedfordshire', 'B-gpe'),
#   ('police', 'O'),
#   ('said', 'O'),
#   ('tuesday', 'B-tim'),
#   ('that', 'O'),
#   ('omar', 'B-per'),
#   ('khayam', 'I-per'),
#   ('wa', 'O'),
#   ('arrested', 'O'),
#   ('in', 'O'),
#   ('bedford', 'B-geo'),
#   ('for', 'O'),
#   ('breaching', 'O'),
#   ('the', 'O'),
#   ('condition', 'O'),
#   ('of', 'O'),
#   ('his', 'O'),
#   ('parole', 'O'),
#   ('.', 'O')],
#  [('police', 'O'),
#   ('said', 'O'),
#   ('the', 'O'),
#   ('british', 'B-org'),
#   ('home', 'I-org'),
#   ('office', 'I-org'),
#   ('sought', 'O'),
#   ('an', 'O'),
#   ('investigation', 'O'),
#   ('of', 'O'),
#   ('khayam', 'B-per'),
#   ("'s", 'O'),
#   ('behavior', 'O'),
#   ('after', 'O'),
#   ('he', 'O'),
#   ('wa', 'O'),
#   ('photographed', 'O'),
#   ('last', 'O'),
#   ('week', 'O'),
#   ('at', 'O'),
#   ('a', 'O'),
#   ('demonstration', 'O'),
#   ('dressed', 'O'),
#   ('in', 'O'),
#   ('fatigue', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('black', 'O'),
#   ('cap', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('a', 'O'),
#   ('bulky', 'O'),
#   ('belt', 'O'),
#   ('.', 'O')],
#  [('a', 'O'),
#   ('home', 'B-org'),
#   ('office', 'I-org'),
#   ('spokesman', 'O'),
#   ('told', 'O'),
#   ('the', 'O'),
#   ('associated', 'B-org'),
#   ('press', 'I-org'),
#   ('that', 'O'),
#   ('if', 'O'),
#   ('the', 'O'),
#   ('behavior', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('paroled', 'O'),
#   ('offender', 'O'),
#   ('give', 'O'),
#   ('cause', 'O'),
#   ('for', 'O'),
#   ('concern', 'O'),
#   (',', 'O'),
#   ('he', 'O'),
#   ('can', 'O'),
#   ('be', 'O'),
#   ('sent', 'O'),
#   ('back', 'O'),
#   ('to', 'O'),
#   ('prison', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('ap', 'B-org'),
#   ('also', 'O'),
#   ('report', 'O'),
#   ('khayam', 'B-per'),
#   ('ha', 'O'),
#   ('been', 'O'),
#   ('on', 'O'),
#   ('parole', 'O'),
#   ('from', 'O'),
#   ('prison', 'O'),
#   ('since', 'O'),
#   ('last', 'O'),
#   ('year', 'O'),
#   ('after', 'O'),
#   ('serving', 'O'),
#   ('half', 'O'),
#   ('his', 'O'),
#   ('six-year', 'O'),
#   ('sentence', 'O'),
#   ('for', 'O'),
#   ('drug', 'O'),
#   ('dealing', 'O'),
#   ('.', 'O')],
#  [('pakistani', 'B-gpe'),
#   ('official', 'O'),
#   ('say', 'O'),
#   ('unidentified', 'O'),
#   ('gunman', 'O'),
#   ('have', 'O'),
#   ('killed', 'O'),
#   ('three', 'O'),
#   ('people', 'O'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('a', 'O'),
#   ('former', 'O'),
#   ('government', 'O'),
#   ('minister', 'O'),
#   (',', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('semi-autonomous', 'O'),
#   ('tribal', 'O'),
#   ('region', 'O'),
#   ('bordering', 'O'),
#   ('afghanistan', 'B-geo'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('official', 'O'),
#   ('say', 'O'),
#   ('prominent', 'O'),
#   ('tribal', 'O'),
#   ('leader', 'O'),
#   ('malik', 'B-per'),
#   ('faridullah', 'I-per'),
#   ('khan', 'I-per'),
#   ('wa', 'O'),
#   ('traveling', 'O'),
#   ('in', 'O'),
#   ('south', 'B-geo'),
#   ('waziristan', 'I-geo'),
#   ('sunday', 'B-tim'),
#   ('when', 'O'),
#   ('his', 'O'),
#   ('vehicle', 'O'),
#   ('wa', 'O'),
#   ('ambushed', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('kani', 'B-geo'),
#   ('wam', 'I-geo'),
#   ('area', 'O'),
#   ('.', 'O')],
#  [('his', 'O'),
#   ('driver', 'O'),
#   ('and', 'O'),
#   ('a', 'O'),
#   ('tribal', 'O'),
#   ('elder', 'O'),
#   ('were', 'O'),
#   ('also', 'O'),
#   ('killed', 'O'),
#   ('.', 'O')],
#  [('no', 'O'),
#   ('one', 'O'),
#   ('ha', 'O'),
#   ('claimed', 'O'),
#   ('responsibility', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('killing', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('ambush', 'O'),
#   ('came', 'O'),
#   ('a', 'O'),
#   ('day', 'O'),
#   ('after', 'O'),
#   ('a', 'O'),
#   ('commander', 'O'),
#   ('of', 'O'),
#   ('pakistani', 'B-gpe'),
#   ('troop', 'O'),
#   ('said', 'O'),
#   ('the', 'O'),
#   ('army', 'O'),
#   ('ha', 'O'),
#   ('almost', 'O'),
#   ('completely', 'O'),
#   ('eliminated', 'O'),
#   ('militant', 'O'),
#   ('in', 'O'),
#   ('south', 'B-geo'),
#   ('waziristan', 'I-geo'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('area', 'O'),
#   ('became', 'O'),
#   ('a', 'O'),
#   ('refuge', 'O'),
#   ('for', 'O'),
#   ('many', 'O'),
#   ('al-qaida', 'B-org'),
#   ('and', 'O'),
#   ('taleban', 'B-org'),
#   ('fighter', 'O'),
#   ('after', 'O'),
#   ('the', 'O'),
#   ('taleban', 'B-org'),
#   ('government', 'O'),
#   ('wa', 'O'),
#   ('ousted', 'O'),
#   ('in', 'O'),
#   ('afghanistan', 'B-geo'),
#   ('in', 'O'),
#   ('2001', 'B-tim'),
#   ('.', 'O')],
#  [('a', 'O'),
#   ('senior', 'O'),
#   ('pakistani', 'B-gpe'),
#   ('military', 'O'),
#   ('official', 'O'),
#   ('say', 'O'),
#   ('pakistan', 'B-gpe'),
#   ('want', 'O'),
#   ('to', 'O'),
#   ('put', 'O'),
#   ('what', 'O'),
#   ('he', 'O'),
#   ('call', 'O'),
#   ('the', 'O'),
#   ('""""', 'O'),
#   ('sordid', 'O'),
#   ('chapter', 'O'),
#   ('""""', 'O'),
#   ('of', 'O'),
#   ('proliferation', 'O'),
#   ('by', 'O'),
#   ('one', 'O'),
#   ('of', 'O'),
#   ('it', 'O'),
#   ('top', 'O'),
#   ('scientist', 'O'),
#   ('behind', 'O'),
#   ('it', 'O'),
#   ('and', 'O'),
#   ('build', 'O'),
#   ('civilian', 'O'),
#   ('nuclear', 'O'),
#   ('tie', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('united', 'B-gpe'),
#   ('state', 'I-gpe'),
#   ('.', 'O')],
#  [('but', 'O'),
#   ('he', 'O'),
#   ('say', 'O'),
#   ('pakistan', 'B-gpe'),
#   ('is', 'O'),
#   ('not', 'O'),
#   ('ready', 'O'),
#   ('to', 'O'),
#   ('make', 'O'),
#   ('the', 'O'),
#   ('nuclear', 'O'),
#   ('scientist', 'O'),
#   (',', 'O'),
#   ('abdul', 'B-per'),
#   ('qadeer', 'I-per'),
#   ('khan', 'I-per'),
#   (',', 'O'),
#   ('available', 'O'),
#   ('for', 'O'),
#   ('direct', 'O'),
#   ('questioning', 'O'),
#   ('over', 'O'),
#   ('his', 'O'),
#   ('sale', 'O'),
#   ('of', 'O'),
#   ('nuclear', 'O'),
#   ('part', 'O'),
#   ('and', 'O'),
#   ('secret', 'O'),
#   ('to', 'O'),
#   ('state', 'O'),
#   ('including', 'O'),
#   ('iran', 'B-gpe'),
#   (',', 'O'),
#   ('libya', 'B-gpe'),
#   ('and', 'O'),
#   ('north', 'B-gpe'),
#   ('korea', 'I-gpe'),
#   ('.', 'O')],
#  [('he', 'O'),
#   ('said', 'O'),
#   ('there', 'O'),
#   ('are', 'O'),
#   ('reason', 'O'),
#   ('of', 'O'),
#   ('national', 'O'),
#   ('sensitivity', 'O'),
#   ('for', 'O'),
#   ('not', 'O'),
#   ('making', 'O'),
#   ('him', 'O'),
#   ('available', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('pakistani', 'B-gpe'),
#   ('official', 'O'),
#   ('wa', 'O'),
#   ('giving', 'O'),
#   ('a', 'O'),
#   ('background', 'O'),
#   ('briefing', 'O'),
#   ('to', 'O'),
#   ('a', 'O'),
#   ('small', 'O'),
#   ('group', 'O'),
#   ('of', 'O'),
#   ('reporter', 'O'),
#   ('in', 'O'),
#   ('washington', 'B-geo'),
#   ('.', 'O')],
#  [('khan', 'B-per'),
#   ('admitted', 'O'),
#   ('in', 'O'),
#   ('2004', 'B-tim'),
#   ('that', 'O'),
#   ('he', 'O'),
#   ('operated', 'O'),
#   ('a', 'O'),
#   ('worldwide', 'O'),
#   ('clandestine', 'O'),
#   ('network', 'O'),
#   ('to', 'O'),
#   ('sell', 'O'),
#   ('nuclear', 'O'),
#   ('technology', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('black', 'O'),
#   ('market', 'O'),
#   ('.', 'O')],
#  [('he', 'O'),
#   ('wa', 'O'),
#   ('placed', 'O'),
#   ('under', 'O'),
#   ('house', 'O'),
#   ('arrest', 'O'),
#   ('in', 'O'),
#   ('islamabad', 'B-geo'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('not', 'O'),
#   ('jailed', 'O'),
#   ('because', 'O'),
#   ('he', 'O'),
#   ('is', 'O'),
#   ('considered', 'O'),
#   ('the', 'O'),
#   ('father', 'O'),
#   ('of', 'O'),
#   ('pakistan', 'B-geo'),
#   ("'s", 'O'),
#   ('nuclear', 'O'),
#   ('bomb', 'O'),
#   ('.', 'O')],
#  [('u.s.', 'B-gpe'),
#   ('army', 'B-org'),
#   ('official', 'O'),
#   ('said', 'O'),
#   ('wednesday', 'B-tim'),
#   ('that', 'O'),
#   ('they', 'O'),
#   ('will', 'O'),
#   ('not', 'O'),
#   ('renew', 'O'),
#   ('a', 'O'),
#   ('controversial', 'O'),
#   ('multi-billion', 'O'),
#   ('dollar', 'O'),
#   ('contract', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('halliburton', 'B-org'),
#   ('company', 'O'),
#   ('to', 'O'),
#   ('provide', 'O'),
#   ('logistical', 'O'),
#   ('support', 'O'),
#   ('to', 'O'),
#   ('u.s.', 'B-gpe'),
#   ('troop', 'O'),
#   ('in', 'O'),
#   ('iraq', 'B-geo'),
#   ('and', 'O'),
#   ('elsewhere', 'O'),
#   ('.', 'O')],
#  [('halliburton', 'B-org'),
#   ('ha', 'O'),
#   ('been', 'O'),
#   ('providing', 'O'),
#   ('a', 'O'),
#   ('long', 'O'),
#   ('list', 'O'),
#   ('of', 'O'),
#   ('service', 'O'),
#   (',', 'O'),
#   ('from', 'O'),
#   ('meal', 'O'),
#   ('to', 'O'),
#   ('communication', 'O'),
#   (',', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('military', 'O'),
#   ('for', 'O'),
#   ('several', 'O'),
#   ('year', 'O'),
#   ('.', 'O')],
#  [('critic', 'O'),
#   ('of', 'O'),
#   ('halliburton', 'B-org'),
#   ('include', 'O'),
#   ('auditor', 'O'),
#   ('and', 'O'),
#   ('congressional', 'O'),
#   ('democrat', 'O'),
#   ('.', 'O')],
#  [('they', 'O'),
#   ('say', 'O'),
#   ('the', 'O'),
#   ('company', 'O'),
#   ('ha', 'O'),
#   ('produced', 'O'),
#   ('some', 'O'),
#   ('shoddy', 'O'),
#   ('work', 'O'),
#   ('and', 'O'),
#   ('charge', 'O'),
#   ('too', 'O'),
#   ('much', 'O'),
#   ('money', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('company', 'O'),
#   ('strongly', 'O'),
#   ('denies', 'O'),
#   ('the', 'O'),
#   ('allegation', 'O'),
#   ('.', 'O')],
#  [('when', 'O'),
#   ('the', 'O'),
#   ('huge', 'O'),
#   ('contract', 'O'),
#   ('is', 'O'),
#   ('put', 'O'),
#   ('out', 'O'),
#   ('for', 'O'),
#   ('re-bidding', 'O'),
#   (',', 'O'),
#   ('several', 'O'),
#   ('company', 'O'),
#   ('will', 'O'),
#   ('get', 'O'),
#   ('a', 'O'),
#   ('chance', 'O'),
#   ('to', 'O'),
#   ('compete', 'O'),
#   ('for', 'O'),
#   ('portion', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('work', 'O'),
#   ('.', 'O')],
#  [('representative', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('asia', 'B-org'),
#   ('pacific', 'I-org'),
#   ('economic', 'I-org'),
#   ('cooperation', 'I-org'),
#   ('business', 'I-org'),
#   ('advisory', 'I-org'),
#   ('council', 'I-org'),
#   ('are', 'O'),
#   ('holding', 'O'),
#   ('meeting', 'O'),
#   ('this', 'O'),
#   ('week', 'O'),
#   ('to', 'O'),
#   ('finalize', 'O'),
#   ('their', 'O'),
#   ('annual', 'O'),
#   ('report', 'O'),
#   ('for', 'O'),
#   ('apec', 'B-org'),
#   ('leader', 'O'),
#   ('who', 'O'),
#   ('will', 'O'),
#   ('hold', 'O'),
#   ('a', 'O'),
#   ('summit', 'O'),
#   ('on', 'O'),
#   ('september', 'B-tim'),
#   ('8', 'I-tim'),
#   ('and', 'O'),
#   ('9', 'B-tim'),
#   ('.', 'O')],
#  [('voa', 'B-org'),
#   ("'s", 'O'),
#   ('nancy-amelia', 'B-per'),
#   ('collins', 'I-per'),
#   ('report', 'O'),
#   ('from', 'O'),
#   ('sydney', 'B-geo'),
#   ('.', 'O')],
#  [('energy', 'O'),
#   (',', 'O'),
#   ('security', 'O'),
#   (',', 'O'),
#   ('climate', 'O'),
#   ('change', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('world', 'B-org'),
#   ('trade', 'I-org'),
#   ('organization', 'I-org'),
#   ("'s", 'O'),
#   ('stalled', 'O'),
#   ('negotiation', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('investment', 'O'),
#   ('are', 'O'),
#   ('all', 'O'),
#   ('expected', 'O'),
#   ('to', 'O'),
#   ('be', 'O'),
#   ('among', 'O'),
#   ('the', 'O'),
#   ('major', 'O'),
#   ('topic', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('annual', 'O'),
#   ('report', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('apec', 'B-org'),
#   ('business', 'I-org'),
#   ('advisory', 'I-org'),
#   ('council', 'I-org'),
#   (',', 'O'),
#   ('known', 'O'),
#   ('a', 'O'),
#   ('abac', 'B-org'),
#   ('.', 'O')],
#  [('tim', 'B-per'),
#   ('harcourt', 'I-per'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('chief', 'O'),
#   ('economist', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('australian', 'B-org'),
#   ('trade', 'I-org'),
#   ('commission', 'I-org'),
#   (',', 'O'),
#   ('say', 'O'),
#   ('abac', 'B-org'),
#   ('play', 'O'),
#   ('an', 'O'),
#   ('important', 'O'),
#   ('role', 'O'),
#   ('by', 'O'),
#   ('informing', 'O'),
#   ('government', 'O'),
#   ('where', 'O'),
#   ('there', 'O'),
#   ('are', 'O'),
#   ('problem', 'O'),
#   ('.', 'O')],
#  [('""""', 'O'),
#   ('the', 'O'),
#   ('most', 'O'),
#   ('important', 'O'),
#   ('thing', 'O'),
#   ('the', 'O'),
#   ('business', 'O'),
#   ('group', 'O'),
#   ('can', 'O'),
#   ('do', 'O'),
#   ('is', 'O'),
#   ('to', 'O'),
#   ('tell', 'O'),
#   ('the', 'O'),
#   ('government', 'O'),
#   ('where', 'O'),
#   ('there', 'O'),
#   ('are', 'O'),
#   ('logjam', 'O'),
#   (',', 'O'),
#   ('where', 'O'),
#   ('there', 'O'),
#   ('are', 'O'),
#   ('obstacle', 'O'),
#   (',', 'O'),
#   ('where', 'O'),
#   ('thing', 'O'),
#   ('can', 'O'),
#   ('improve', 'O'),
#   (',', 'O'),
#   ('""""', 'O'),
#   ('harcourt', 'B-per'),
#   ('said', 'O'),
#   ('.', 'O')],
#  [('""""', 'O'),
#   ('i', 'O'),
#   ('think', 'O'),
#   ('actually', 'O'),
#   ('abac', 'B-org'),
#   ('ha', 'O'),
#   ('played', 'O'),
#   ('a', 'O'),
#   ('pretty', 'O'),
#   ('good', 'O'),
#   ('leadership', 'O'),
#   ('on', 'O'),
#   ('that', 'O'),
#   ('in', 'O'),
#   ('talking', 'O'),
#   ('about', 'O'),
#   ('trade', 'O'),
#   ('facilitation', 'O'),
#   ('and', 'O'),
#   ('basically', 'O'),
#   ('making', 'O'),
#   ('sure', 'O'),
#   ('standard', 'O'),
#   ('are', 'O'),
#   ('consistent', 'O'),
#   ('and', 'O'),
#   ('harmonious', 'O'),
#   ('across', 'O'),
#   ('the', 'O'),
#   ('region', 'O'),
#   ('.', 'O'),
#   ('""""', 'O')],
#  [('abac', 'B-org'),
#   ('comprises', 'O'),
#   ('up', 'O'),
#   ('to', 'O'),
#   ('three', 'O'),
#   ('member', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('private', 'O'),
#   ('sector', 'O'),
#   ('of', 'O'),
#   ('each', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('21', 'O'),
#   ('economy', 'O'),
#   ('that', 'O'),
#   ('make', 'O'),
#   ('up', 'O'),
#   ('apec', 'B-org'),
#   ('.', 'O')],
#  [('it', 'O'),
#   ('meet', 'O'),
#   ('three', 'O'),
#   ('time', 'O'),
#   ('a', 'O'),
#   ('year', 'O'),
#   ('.', 'O')],
#  [('it', 'O'),
#   ('wa', 'O'),
#   ('made', 'O'),
#   ('a', 'O'),
#   ('permanent', 'O'),
#   ('body', 'O'),
#   ('in', 'O'),
#   ('1995', 'B-tim'),
#   ('to', 'O'),
#   ('provide', 'O'),
#   ('an', 'O'),
#   ('independent', 'O'),
#   ('business', 'O'),
#   ('perspective', 'O'),
#   ('within', 'O'),
#   ('apec', 'B-org'),
#   ('.', 'O')],
#  [('member', 'O'),
#   ('represent', 'O'),
#   ('a', 'O'),
#   ('range', 'O'),
#   ('of', 'O'),
#   ('business', 'O'),
#   ('sector', 'O'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('medium', 'O'),
#   ('and', 'O'),
#   ('small', 'O'),
#   ('business', 'O'),
#   ('.', 'O')],
#  [('abac', 'B-org'),
#   ('say', 'O'),
#   ('there', 'O'),
#   ('is', 'O'),
#   ('a', 'O'),
#   ('need', 'O'),
#   ('for', 'O'),
#   ('business', 'O'),
#   ('to', 'O'),
#   ('improve', 'O'),
#   ('energy', 'O'),
#   ('efficiency', 'O'),
#   ('and', 'O'),
#   ('to', 'O'),
#   ('encourage', 'O'),
#   ('conservation', 'O'),
#   ('practice', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('is', 'O'),
#   ('expected', 'O'),
#   ('to', 'O'),
#   ('include', 'O'),
#   ('this', 'O'),
#   ('in', 'O'),
#   ('it', 'O'),
#   ('annual', 'O'),
#   ('report', 'O'),
#   ('.', 'O')],
#  [('harcourt', 'B-per'),
#   (',', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('australian', 'B-org'),
#   ('trade', 'I-org'),
#   ('commission', 'I-org'),
#   (',', 'O'),
#   ('say', 'O'),
#   ('the', 'O'),
#   ('abac', 'B-org'),
#   ('report', 'O'),
#   ('will', 'O'),
#   ('also', 'O'),
#   ('discus', 'O'),
#   ('way', 'O'),
#   ('to', 'O'),
#   ('enhance', 'O'),
#   ('regional', 'O'),
#   ('cooperation', 'O'),
#   ('.', 'O')],
#  [('""""', 'O'),
#   ('i', 'O'),
#   ('reckon', 'O'),
#   ('they', 'O'),
#   ("'ll", 'O'),
#   ('talk', 'O'),
#   ('a', 'O'),
#   ('little', 'O'),
#   ('bit', 'O'),
#   ('about', 'O'),
#   ('custom', 'O'),
#   ('and', 'O'),
#   ('quarantine', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('little', 'O'),
#   ('bit', 'O'),
#   ('about', 'O'),
#   ('having', 'O'),
#   ('consistent', 'O'),
#   ('security', 'O'),
#   ('arrangement', 'O'),
#   ('around', 'O'),
#   ('the', 'O'),
#   ('region', 'O'),
#   (',', 'O'),
#   ('""""', 'O'),
#   ('harcourt', 'B-per'),
#   ('said', 'O'),
#   ('.', 'O')],
#  [('""""', 'O'),
#   ('and', 'O'),
#   ('i', 'O'),
#   ('think', 'O'),
#   ('they', 'O'),
#   ("'ll", 'O'),
#   ('want', 'O'),
#   ('a', 'O'),
#   ('one-stop', 'O'),
#   ('shop', 'O'),
#   ('in', 'O'),
#   ('term', 'O'),
#   ('of', 'O'),
#   ('combining', 'O'),
#   ('security', 'O'),
#   (',', 'O'),
#   ('immigration', 'O'),
#   (',', 'O'),
#   ('custom', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('quarantine', 'O'),
#   ('together', 'O'),
#   ('...', 'O'),
#   ('just', 'O'),
#   ('to', 'O'),
#   ('make', 'O'),
#   ('sure', 'O'),
#   ('it', 'O'),
#   ("'s", 'O'),
#   ('more', 'O'),
#   ('streamlined', 'O'),
#   ('and', 'O'),
#   ('provides', 'O'),
#   ('more', 'O'),
#   ('certainty', 'O'),
#   ('.', 'O'),
#   ('""""', 'O')],
#  [('abac', 'B-org'),
#   ('is', 'O'),
#   ('the', 'O'),
#   ('only', 'O'),
#   ('non-governmental', 'O'),
#   ('body', 'O'),
#   ('that', 'O'),
#   ('ha', 'O'),
#   ('an', 'O'),
#   ('official', 'O'),
#   ('role', 'O'),
#   ('and', 'O'),
#   ('formal', 'O'),
#   ('dialogue', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('leader', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('apec', 'B-org'),
#   ('economy', 'O'),
#   ('.', 'O')],
#  [('it', 'O'),
#   ('will', 'O'),
#   ('present', 'O'),
#   ('it', 'O'),
#   ('annual', 'O'),
#   ('report', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('apec', 'B-org'),
#   ('leader', 'O'),
#   ('meeting', 'O'),
#   ('on', 'O'),
#   ('saturday', 'B-tim'),
#   ('.', 'O')],
#  [('sudan', 'B-gpe'),
#   ("'s", 'O'),
#   ('government', 'O'),
#   ('say', 'O'),
#   ('it', 'O'),
#   ('will', 'O'),
#   ('order', 'O'),
#   ('troop', 'O'),
#   ('to', 'O'),
#   ('end', 'O'),
#   ('attack', 'O'),
#   ('immediately', 'O'),
#   ('in', 'O'),
#   ('darfur', 'B-geo'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('is', 'O'),
#   ('asking', 'O'),
#   ('rebel', 'O'),
#   ('to', 'O'),
#   ('do', 'O'),
#   ('the', 'O'),
#   ('same', 'O'),
#   ('.', 'O')],
#  [('foreign', 'B-per'),
#   ('minister', 'I-per'),
#   ('mustafa', 'I-per'),
#   ('osman', 'I-per'),
#   ('ismail', 'I-per'),
#   ('say', 'O'),
#   ('sudanese', 'B-gpe'),
#   ('troop', 'O'),
#   ('will', 'O'),
#   ('also', 'O'),
#   ('withdraw', 'O'),
#   ('to', 'O'),
#   ('position', 'O'),
#   ('held', 'O'),
#   ('before', 'O'),
#   ('an', 'O'),
#   ('april', 'B-tim'),
#   ('cease-fire', 'O'),
#   (',', 'O'),
#   ('if', 'O'),
#   ('rebel', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('western', 'O'),
#   ('region', 'O'),
#   ('agree', 'O'),
#   ('to', 'O'),
#   ('stop', 'O'),
#   ('attack', 'O'),
#   ('.', 'O')],
#  [('mr.', 'B-per'),
#   ('ismail', 'I-per'),
#   ('announced', 'O'),
#   ('the', 'O'),
#   ('decision', 'O'),
#   ('after', 'O'),
#   ('meeting', 'O'),
#   ('with', 'O'),
#   ('official', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('united', 'B-org'),
#   ('nation', 'I-org'),
#   ('and', 'O'),
#   ('african', 'B-org'),
#   ('union', 'I-org'),
#   ('in', 'O'),
#   ('khartoum', 'B-geo'),
#   ('sunday', 'B-tim'),
#   ('.', 'O')],
#  [('in', 'O'),
#   ('recent', 'O'),
#   ('week', 'O'),
#   (',', 'O'),
#   ('au', 'B-org'),
#   ('official', 'O'),
#   ('say', 'O'),
#   ('sudanese', 'B-gpe'),
#   ('troop', 'O'),
#   ('and', 'O'),
#   ('rebel', 'O'),
#   ('have', 'O'),
#   ('repeatedly', 'O'),
#   ('violated', 'O'),
#   ('the', 'O'),
#   ('april', 'B-tim'),
#   ('truce', 'O'),
#   ('.', 'O')],
#  [('saturday', 'B-tim'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('head', 'O'),
#   ('of', 'O'),
#   ('au', 'B-org'),
#   ('force', 'O'),
#   ('in', 'O'),
#   ('darfur', 'B-geo'),
#   ('accused', 'O'),
#   ('sudanese', 'B-gpe'),
#   ('government', 'O'),
#   ('helicopter', 'O'),
#   ('of', 'O'),
#   ('bombing', 'O'),
#   ('rebel', 'O'),
#   ('site', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('south', 'B-geo'),
#   ('darfur', 'I-geo'),
#   ('village', 'O'),
#   ('of', 'O'),
#   ('labado', 'B-geo'),
#   ('.', 'O')],
#  [('khartoum', 'B-gpe'),
#   ('say', 'O'),
#   ('troop', 'O'),
#   ('were', 'O'),
#   ('defending', 'O'),
#   ('their', 'O'),
#   ('position', 'O'),
#   ('from', 'O'),
#   ('rebel', 'O'),
#   ('attack', 'O'),
#   ('.', 'O')],
#  [('aid', 'O'),
#   ('worker', 'O'),
#   ('say', 'O'),
#   ('some', 'O'),
#   ('relief', 'O'),
#   ('effort', 'O'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('suspended', 'O'),
#   ('in', 'O'),
#   ('south', 'B-geo'),
#   ('darfur', 'I-geo'),
#   ('due', 'O'),
#   ('to', 'O'),
#   ('recent', 'O'),
#   ('attack', 'O'),
#   ('.', 'O')],
#  [('indonesian', 'B-gpe'),
#   ('police', 'O'),
#   ('have', 'O'),
#   ('arrested', 'O'),
#   ('three', 'O'),
#   ('men', 'O'),
#   ('in', 'O'),
#   ('connection', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('october', 'B-tim'),
#   ('1', 'I-tim'),
#   ('bali', 'B-geo'),
#   ('bombing', 'O'),
#   ('that', 'O'),
#   ('left', 'O'),
#   ('23', 'O'),
#   ('people', 'O'),
#   ('dead', 'O'),
#   ('.', 'O')],
#  [('indonesian', 'B-gpe'),
#   ('police', 'O'),
#   ('said', 'O'),
#   ('wednesday', 'B-tim'),
#   ('the', 'O'),
#   ('men', 'O'),
#   ('were', 'O'),
#   ('flown', 'O'),
#   ('to', 'O'),
#   ('bali', 'B-geo'),
#   ('from', 'O'),
#   ('neighboring', 'O'),
#   ('java', 'B-geo'),
#   ('island', 'O'),
#   ('for', 'O'),
#   ('questioning', 'O'),
#   ('at', 'O'),
#   ('bali', 'B-geo'),
#   ('police', 'O'),
#   ('headquarters', 'O'),
#   ('.', 'O')],
#  [('australian', 'B-gpe'),
#   ('and', 'O'),
#   ('french', 'B-gpe'),
#   ('news', 'O'),
#   ('agency', 'O'),
#   ('say', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('one', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('men', 'O'),
#   ('arrested', 'O'),
#   ('(', 'O'),
#   ('cholily', 'B-per'),
#   (')', 'O'),
#   ('wa', 'O'),
#   ('captured', 'O'),
#   ('during', 'O'),
#   ('a', 'O'),
#   ('series', 'O'),
#   ('of', 'O'),
#   ('counter-terrorism', 'O'),
#   ('raid', 'O'),
#   ('last', 'O'),
#   ('week', 'O'),
#   ('in', 'O'),
#   ('indonesia', 'B-geo'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('raid', 'O'),
#   ('ended', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('death', 'O'),
#   ('of', 'O'),
#   ('alleged', 'O'),
#   ('extremist', 'O'),
#   ('bombmaker', 'O'),
#   ('azahari', 'B-per'),
#   ('bin', 'I-per'),
#   ('husin', 'I-per'),
#   ('.', 'O')],
#  [('indonesian', 'B-gpe'),
#   ('authority', 'O'),
#   ('blame', 'O'),
#   ('azahari', 'B-per'),
#   ('bin', 'I-per'),
#   ('husin', 'I-per'),
#   ('for', 'O'),
#   ('orchestrating', 'O'),
#   ('last', 'O'),
#   ('month', 'O'),
#   ("'s", 'O'),
#   ('attack', 'O'),
#   ('in', 'O'),
#   ('bali', 'B-geo'),
#   ('a', 'O'),
#   ('well', 'O'),
#   ('a', 'O'),
#   ('the', 'O'),
#   ('2002', 'B-tim'),
#   ('bali', 'B-geo'),
#   ('bombing', 'O'),
#   ('that', 'O'),
#   ('killed', 'O'),
#   ('more', 'O'),
#   ('than', 'O'),
#   ('200', 'O'),
#   ('people', 'O'),
#   ('.', 'O')],
#  [('gunman', 'O'),
#   ('have', 'O'),
#   ('shot', 'O'),
#   ('and', 'O'),
#   ('killed', 'O'),
#   ('a', 'O'),
#   ('roman', 'B-org'),
#   ('catholic', 'I-org'),
#   ('nun', 'O'),
#   ('and', 'O'),
#   ('her', 'O'),
#   ('bodyguard', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('hospital', 'O'),
#   ('where', 'O'),
#   ('she', 'O'),
#   ('worked', 'O'),
#   ('in', 'O'),
#   ('islamist-controlled', 'O'),
#   ('mogadishu', 'B-geo'),
#   (',', 'O'),
#   ('somalia', 'B-geo'),
#   ('.', 'O')],
#  [('some', 'O'),
#   ('witness', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('sunday', 'B-tim'),
#   ('shooting', 'O'),
#   ('said', 'O'),
#   ('they', 'O'),
#   ('feared', 'O'),
#   ('the', 'O'),
#   ('attack', 'O'),
#   ('wa', 'O'),
#   ('linked', 'O'),
#   ('to', 'O'),
#   ('muslim', 'O'),
#   ('anger', 'O'),
#   ('toward', 'O'),
#   ('pope', 'B-per'),
#   ('benedict', 'I-per'),
#   ('.', 'O')],
#  [('two', 'O'),
#   ('men', 'O'),
#   ('with', 'O'),
#   ('pistol', 'O'),
#   ('attacked', 'O'),
#   ('the', 'O'),
#   ('nun', 'O'),
#   (',', 'O'),
#   ('sister', 'B-per'),
#   ('leonella', 'I-per'),
#   ('sgorbati', 'I-per'),
#   (',', 'O'),
#   ('after', 'O'),
#   ('she', 'O'),
#   ('finished', 'O'),
#   ('teaching', 'O'),
#   ('a', 'O'),
#   ('medical', 'O'),
#   ('school', 'O'),
#   ('class', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('hospital', 'O'),
#   ('in', 'O'),
#   ('southern', 'O'),
#   ('mogadishu', 'B-geo'),
#   ('.', 'O')],
#  [('official', 'O'),
#   ('say', 'O'),
#   ('one', 'O'),
#   ('suspect', 'O'),
#   ('wa', 'O'),
#   ('arrested', 'O'),
#   ('.', 'O')],
#  [('in', 'O'),
#   ('rome', 'B-geo'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('vatican', 'B-org'),
#   ('spokesman', 'O'),
#   ('deplored', 'O'),
#   ('the', 'O'),
#   ('attack', 'O'),
#   ('and', 'O'),
#   ('said', 'O'),
#   ('he', 'O'),
#   ('hoped', 'O'),
#   ('it', 'O'),
#   ('wa', 'O'),
#   ('an', 'O'),
#   ('isolated', 'O'),
#   ('event', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('not', 'O'),
#   ('irrationality', 'O'),
#   ('arising', 'O'),
#   ('from', 'O'),
#   ('comment', 'O'),
#   ('made', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('pope', 'O'),
#   ('which', 'O'),
#   ('angered', 'O'),
#   ('some', 'O'),
#   ('muslim', 'O'),
#   ('.', 'O')],
#  [('authority', 'O'),
#   ('in', 'O'),
#   ('mogadishu', 'B-geo'),
#   ('have', 'O'),
#   ('not', 'O'),
#   ('determined', 'O'),
#   ('a', 'O'),
#   ('motive', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('shooting', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('pope', 'O'),
#   ('ha', 'O'),
#   ('said', 'O'),
#   ('he', 'O'),
#   ('meant', 'O'),
#   ('no', 'O'),
#   ('offense', 'O'),
#   ('to', 'O'),
#   ('muslim', 'O'),
#   ('when', 'O'),
#   ('he', 'O'),
#   ('quoted', 'O'),
#   ('a', 'O'),
#   ('14', 'O'),
#   ('century', 'O'),
#   ('byzantine', 'B-per'),
#   ('emperor', 'O'),
#   ('a', 'O'),
#   ('saying', 'O'),
#   ('some', 'O'),
#   ('teaching', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('prophet', 'B-per'),
#   ('muhammed', 'I-per'),
#   ('brought', 'O'),
#   ('evil', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('world', 'O'),
#   ('.', 'O')],
#  [('pakistani', 'B-gpe'),
#   ('force', 'O'),
#   ('have', 'O'),
#   ('targeted', 'O'),
#   ('militant', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('northwest', 'O'),
#   ('for', 'O'),
#   ('a', 'O'),
#   ('third', 'O'),
#   ('day', 'O'),
#   (',', 'O'),
#   ('launching', 'O'),
#   ('airstrikes', 'O'),
#   ('that', 'O'),
#   ('they', 'O'),
#   ('say', 'O'),
#   ('killed', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('nine', 'O'),
#   ('suspected', 'O'),
#   ('insurgent', 'O'),
#   ('.', 'O')],
#  [('helicopter', 'O'),
#   ('gunships', 'O'),
#   ('saturday', 'B-tim'),
#   ('pounded', 'O'),
#   ('militant', 'O'),
#   ('hideout', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('orakzai', 'B-geo'),
#   ('tribal', 'O'),
#   ('region', 'O'),
#   (',', 'O'),
#   ('where', 'O'),
#   ('many', 'O'),
#   ('taliban', 'B-org'),
#   ('militant', 'O'),
#   ('are', 'O'),
#   ('believed', 'O'),
#   ('to', 'O'),
#   ('have', 'O'),
#   ('fled', 'O'),
#   ('to', 'O'),
#   ('avoid', 'O'),
#   ('an', 'O'),
#   ('earlier', 'O'),
#   ('military', 'O'),
#   ('offensive', 'O'),
#   ('in', 'O'),
#   ('nearby', 'O'),
#   ('south', 'B-geo'),
#   ('waziristan', 'I-geo'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('pakistani', 'B-gpe'),
#   ('military', 'O'),
#   ('launched', 'O'),
#   ('it', 'O'),
#   ('offensive', 'O'),
#   ('in', 'O'),
#   ('orakzai', 'B-geo'),
#   ('to', 'O'),
#   ('hunt', 'O'),
#   ('taliban', 'B-org'),
#   ('insurgent', 'O'),
#   ('.', 'O')],
#  [('so', 'O'),
#   ('far', 'O'),
#   (',', 'O'),
#   ('nearly', 'O'),
#   ('100', 'O'),
#   ('militant', 'O'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('reported', 'O'),
#   ('killed', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('region', 'O'),
#   ('since', 'O'),
#   ('thursday', 'B-tim'),
#   ('.', 'O')],
#  [('on', 'O'),
#   ('friday', 'B-tim'),
#   (',', 'O'),
#   ('five', 'O'),
#   ('soldier', 'O'),
#   ('were', 'O'),
#   ('killed', 'O'),
#   ('when', 'O'),
#   ('dozen', 'O'),
#   ('of', 'O'),
#   ('militant', 'O'),
#   ('stormed', 'O'),
#   ('a', 'O'),
#   ('military', 'O'),
#   ('checkpoint', 'O'),
#   ('in', 'O'),
#   ('orakzai', 'B-geo'),
#   ('.', 'O')],
#  [('at', 'O'),
#   ('least', 'O'),
#   ('32', 'O'),
#   ('suspected', 'O'),
#   ('militant', 'O'),
#   ('were', 'O'),
#   ('killed', 'O'),
#   ('when', 'O'),
#   ('troop', 'O'),
#   ('launched', 'O'),
#   ('a', 'O'),
#   ('counter-attack', 'O'),
#   ('.', 'O')],
#  [('elsewhere', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('northwest', 'O'),
#   (',', 'O'),
#   ('authority', 'O'),
#   ('on', 'O'),
#   ('saturday', 'B-tim'),
#   ('found', 'O'),
#   ('the', 'O'),
#   ('body', 'O'),
#   ('of', 'O'),
#   ('six', 'O'),
#   ('people', 'O'),
#   ('who', 'O'),
#   ('had', 'O'),
#   ('been', 'O'),
#   ('shot', 'O'),
#   ('dead', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('kurram', 'B-geo'),
#   ('region', 'O'),
#   ('along', 'O'),
#   ('the', 'O'),
#   ('afghan', 'B-gpe'),
#   ('border', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('six', 'O'),
#   ('were', 'O'),
#   ('kidnapped', 'O'),
#   ('a', 'O'),
#   ('few', 'O'),
#   ('day', 'O'),
#   ('ago', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('u.s.', 'B-org'),
#   ('military', 'O'),
#   ('in', 'O'),
#   ('afghanistan', 'B-geo'),
#   ('say', 'O'),
#   ('coalition', 'O'),
#   ('force', 'O'),
#   ('killed', 'O'),
#   ('14', 'O'),
#   ('taleban', 'B-org'),
#   ('militant', 'O'),
#   ('in', 'O'),
#   ('separate', 'O'),
#   ('clash', 'O'),
#   ('this', 'O'),
#   ('week', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('military', 'O'),
#   ('said', 'O'),
#   ('saturday', 'B-tim'),
#   ('13', 'O'),
#   ('guerrilla', 'O'),
#   ('were', 'O'),
#   ('killed', 'O'),
#   ('in', 'O'),
#   ('two', 'O'),
#   ('encounter', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('central', 'O'),
#   ('province', 'O'),
#   ('of', 'O'),
#   ('uruzgan', 'B-geo'),
#   ('.', 'O')],
#  [('one', 'O'),
#   ('afghan', 'B-gpe'),
#   ('soldier', 'O'),
#   ('wa', 'O'),
#   ('killed', 'O'),
#   ('and', 'O'),
#   ('four', 'O'),
#   ('others', 'O'),
#   (',', 'O'),
#   ('including', 'O'),
#   ('a', 'O'),
#   ('u.s.', 'B-gpe'),
#   ('soldier', 'O'),
#   (',', 'O'),
#   ('were', 'O'),
#   ('injured', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('fighting', 'O'),
#   ('.', 'O')],
#  [('another', 'O'),
#   ('militant', 'O'),
#   ('wa', 'O'),
#   ('killed', 'O'),
#   ('by', 'O'),
#   ('u.s.', 'B-gpe'),
#   ('troop', 'O'),
#   ('in', 'O'),
#   ('eastern', 'O'),
#   ('paktika', 'B-geo'),
#   ('province', 'O'),
#   ('.', 'O')],
#  [('separately', 'O'),
#   (',', 'O'),
#   ('official', 'O'),
#   ('say', 'O'),
#   ('four', 'O'),
#   ('british', 'B-gpe'),
#   ('soldier', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('nato-led', 'O'),
#   ('peacekeeping', 'O'),
#   ('mission', 'O'),
#   ('were', 'O'),
#   ('wounded', 'O'),
#   ('early', 'O'),
#   ('saturday', 'B-tim'),
#   ('in', 'O'),
#   ('an', 'O'),
#   ('attack', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('northern', 'O'),
#   ('city', 'O'),
#   ('of', 'O'),
#   ('mazar-e-sharif', 'B-geo'),
#   ('.', 'O')],
#  [('it', 'O'),
#   ('wa', 'O'),
#   ('not', 'O'),
#   ('immediately', 'O'),
#   ('clear', 'O'),
#   ('what', 'O'),
#   ('motivated', 'O'),
#   ('the', 'O'),
#   ('attack', 'O'),
#   ('.', 'O')],
#  [('taleban', 'B-org'),
#   ('rebel', 'O'),
#   ('are', 'O'),
#   ('not', 'O'),
#   ('known', 'O'),
#   ('to', 'O'),
#   ('operate', 'O'),
#   ('in', 'O'),
#   ('northern', 'O'),
#   ('afghanistan', 'B-geo'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('area', 'O'),
#   ('ha', 'O'),
#   ('been', 'O'),
#   ('spared', 'O'),
#   ('much', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('bloodshed', 'O'),
#   ('that', 'O'),
#   ('ha', 'O'),
#   ('plagued', 'O'),
#   ('southern', 'O'),
#   ('and', 'O'),
#   ('eastern', 'O'),
#   ('region', 'O'),
#   ('.', 'O')],
#  [('russian', 'B-gpe'),
#   ('official', 'O'),
#   ('say', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('five', 'O'),
#   ('more', 'O'),
#   ('people', 'O'),
#   ('have', 'O'),
#   ('died', 'O'),
#   ('from', 'O'),
#   ('a', 'O'),
#   ('wave', 'O'),
#   ('of', 'O'),
#   ('extremely', 'O'),
#   ('cold', 'O'),
#   ('weather', 'O'),
#   ('gripping', 'O'),
#   ('the', 'O'),
#   ('nation', 'O'),
#   (',', 'O'),
#   ('bringing', 'O'),
#   ('the', 'O'),
#   ('death', 'O'),
#   ('toll', 'O'),
#   ('to', 'O'),
#   ('43', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('past', 'O'),
#   ('week', 'O'),
#   ('.', 'O')],
#  [('emergency', 'O'),
#   ('medical', 'O'),
#   ('official', 'O'),
#   ('say', 'O'),
#   ('the', 'O'),
#   ('five', 'O'),
#   ('victim', 'O'),
#   ('died', 'O'),
#   ('in', 'O'),
#   ('moscow', 'B-geo'),
#   ('from', 'O'),
#   ('exposure', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('another', 'O'),
#   ('19', 'O'),
#   ('people', 'O'),
#   ('are', 'O'),
#   ('hospitalized', 'O'),
#   ('with', 'O'),
#   ('hypothermia', 'O'),
#   ('.', 'O')],
#  [('russia', 'B-geo'),
#   ("'s", 'O'),
#   ('itar-tass', 'B-org'),
#   ('news', 'O'),
#   ('agency', 'O'),
#   ('quote', 'O'),
#   ('a', 'O'),
#   ('medical', 'O'),
#   ('official', 'O'),
#   ('a', 'O'),
#   ('saying', 'O'),
#   ('some', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('victim', 'O'),
#   ('were', 'O'),
#   ('intoxicated', 'O'),
#   ('or', 'O'),
#   ('homeless', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('unusually', 'O'),
#   ('cold', 'O'),
#   ('weather', 'O'),
#   ('is', 'O'),
#   ('affecting', 'O'),
#   ('russia', 'B-geo'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('baltic', 'B-geo'),
#   ('state', 'I-geo'),
#   ('of', 'O'),
#   ('lithuania', 'B-geo'),
# ...
#   ('.', 'O')],
#  [('burmese', 'B-gpe'),
#   ('pro-democracy', 'O'),
#   ('leader', 'O'),
#   ('aung', 'B-per'),
#   ('san', 'I-per'),
#   ('suu', 'I-per'),
#   ('kyi', 'I-per'),
#   ('met', 'O'),
#   ('saturday', 'B-tim'),
#   ('with', 'O'),
#   ('a', 'O'),
#   ('top', 'O'),
#   ('united', 'B-org'),
#   ('nation', 'I-org'),
#   ('official', 'O'),
#   ('.', 'O')],
#  [('aung', 'B-per'),
#   ('san', 'I-per'),
#   ('suu', 'I-per'),
#   ('kyi', 'I-per'),
#   ('spoke', 'O'),
#   ('to', 'O'),
#   ('reporter', 'O'),
#   ('saturday', 'B-tim'),
#   ('at', 'O'),
#   ('her', 'O'),
#   ('lakeside', 'O'),
#   ('home', 'O'),
#   ('in', 'O'),
#   ('rangoon', 'B-geo'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('praised', 'O'),
#   ('the', 'O'),
#   ('talk', 'O'),
#   ('with', 'O'),
#   ('vijay', 'B-per'),
#   ('nambiar', 'I-per'),
#   (',', 'O'),
#   ('chief', 'O'),
#   ('of', 'O'),
#   ('staff', 'O'),
#   ('for', 'O'),
#   ('u.n.', 'B-per'),
#   ('secretary-general', 'B-org'),
#   ('ban', 'B-per'),
#   ('ki-moon', 'I-per'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('65-year-old', 'O'),
#   ('nobel', 'B-art'),
#   ('peace', 'O'),
#   ('prize', 'O'),
#   ('laureate', 'O'),
#   ('ha', 'O'),
#   ('been', 'O'),
#   ('vocal', 'O'),
#   ('about', 'O'),
#   ('pursuing', 'O'),
#   ('democratic', 'O'),
#   ('reform', 'O'),
#   ('since', 'O'),
#   ('her', 'O'),
#   ('release', 'B-tim'),
#   ('november', 'I-tim'),
#   ('13', 'I-tim'),
#   ('from', 'I-tim'),
#   ('more', 'I-tim'),
#   ('than', 'I-tim'),
#   ('seven', 'I-tim'),
#   ('year', 'O'),
#   ('of', 'O'),
#   ('house', 'O'),
#   ('arrest', 'O'),
#   ('.', 'O')],
#  [('but', 'O'),
#   ('she', 'O'),
#   ('ha', 'O'),
#   ('also', 'O'),
#   ('been', 'O'),
#   ('careful', 'O'),
#   ('not', 'O'),
#   ('to', 'O'),
#   ('verbally', 'O'),
#   ('challenge', 'O'),
#   ('burma', 'B-geo'),
#   ("'s", 'O'),
#   ('ruling', 'O'),
#   ('general', 'O'),
#   ('.', 'O')],
#  [('nambiar', 'B-per'),
#   ('also', 'O'),
#   ('met', 'O'),
#   ('saturday', 'B-tim'),
#   ('with', 'O'),
#   ('burma', 'B-org'),
#   ("'s", 'O'),
#   ('foreign', 'O'),
#   ('minister', 'O'),
#   ('.', 'O')],
#  [('he', 'O'),
#   ('also', 'O'),
#   ('planned', 'O'),
#   ('to', 'O'),
#   ('meet', 'O'),
#   ('with', 'O'),
#   ('diplomat', 'O'),
#   ('and', 'O'),
#   ('recently-elected', 'O'),
#   ('lawmaker', 'O'),
#   ('.', 'O')],
#  [('pakistani', 'B-gpe'),
#   ('official', 'O'),
#   ('say', 'O'),
#   ('security', 'O'),
#   ('force', 'O'),
#   ('have', 'O'),
#   ('arrested', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('three', 'O'),
#   ('al-qaida', 'B-org'),
#   ('suspect', 'O'),
#   ('after', 'O'),
#   ('a', 'O'),
#   ('gunfight', 'O'),
#   ('near', 'O'),
#   ('the', 'O'),
#   ('afghan', 'B-gpe'),
#   ('border', 'O'),
#   ('.', 'O')],
#  [('they', 'O'),
#   ('say', 'O'),
#   ('police', 'O'),
#   ('opened', 'O'),
#   ('fire', 'O'),
#   ('monday', 'B-tim'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('car', 'O'),
#   ('carrying', 'O'),
#   ('the', 'O'),
#   ('suspect', 'O'),
#   ('outside', 'O'),
#   ('the', 'O'),
#   ('northwestern', 'O'),
#   ('city', 'O'),
#   ('of', 'O'),
#   ('peshawar', 'B-geo'),
#   ('and', 'O'),
#   ('forced', 'O'),
#   ('it', 'O'),
#   ('to', 'O'),
#   ('stop', 'O'),
#   ('.', 'O')],
#  [('report', 'O'),
#   ('say', 'O'),
#   ('one', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('suspect', 'O'),
#   ('escaped', 'O'),
#   ('while', 'O'),
#   ('the', 'O'),
#   ('others', 'O'),
#   ('were', 'O'),
#   ('arrested', 'O'),
#   ('.', 'O')],
#  [('this', 'O'),
#   ('come', 'O'),
#   ('le', 'O'),
#   ('than', 'O'),
#   ('a', 'O'),
#   ('week', 'O'),
#   ('after', 'O'),
#   ('pakistani', 'B-org'),
#   ('official', 'O'),
#   ('said', 'O'),
#   ('a', 'O'),
#   ('senior', 'O'),
#   ('al-qaida', 'B-org'),
#   ('explosive', 'O'),
#   ('expert', 'O'),
#   ('wa', 'O'),
#   ('killed', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('raid', 'O'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('suspected', 'O'),
#   ('insurgent', 'O'),
#   ('hideout', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('tribal', 'O'),
#   ('region', 'O'),
#   ('of', 'O'),
#   ('north', 'B-geo'),
#   ('waziristan', 'I-geo'),
#   ('bordering', 'O'),
#   ('afghanistan', 'B-geo'),
#   ('.', 'O')],
#  [('egyptian-born', 'O'),
#   ('muhsin', 'B-per'),
#   ('musa', 'I-per'),
#   ('matwali', 'I-per'),
#   ('atwah', 'I-per'),
#   ('wa', 'O'),
#   ('wanted', 'O'),
#   ('in', 'O'),
#   ('connection', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('1998', 'B-tim'),
#   ('bombing', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('u.s.', 'B-org'),
#   ('embassy', 'O'),
#   ('in', 'O'),
#   ('kenya', 'B-geo'),
#   ('and', 'O'),
#   ('tanzania', 'B-geo'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('united', 'B-geo'),
#   ('state', 'I-geo'),
#   ('offered', 'O'),
#   ('a', 'O'),
#   ('$', 'O'),
#   ('5', 'O'),
#   ('million', 'O'),
#   ('reward', 'O'),
#   ('for', 'O'),
#   ('his', 'O'),
#   ('capture', 'O'),
#   ('.', 'O')],
#  [('six', 'O'),
#   ('other', 'O'),
#   ('islamic', 'O'),
#   ('militant', 'O'),
#   ('were', 'O'),
#   ('killed', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('raid', 'O'),
#   ('.', 'O')],
#  [('rebel', 'O'),
#   ('in', 'O'),
#   ('eastern', 'B-geo'),
#   ('sudan', 'I-geo'),
#   ('say', 'O'),
#   ('government', 'O'),
#   ('war', 'O'),
#   ('plane', 'O'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('bombing', 'O'),
#   ('a', 'O'),
#   ('rebel', 'O'),
#   ('area', 'O'),
#   ('near', 'O'),
#   ('the', 'O'),
#   ('border', 'O'),
#   ('with', 'O'),
#   ('eritrea', 'B-geo'),
#   (',', 'O'),
#   ('wounding', 'O'),
#   ('several', 'O'),
#   ('people', 'O'),
#   ('.', 'O')],
#  [('a', 'O'),
#   ('spokesman', 'O'),
#   ('with', 'O'),
#   ('rebel', 'O'),
#   ('known', 'O'),
#   ('a', 'O'),
#   ('the', 'O'),
#   ('eastern', 'B-org'),
#   ('front', 'I-org'),
#   ('said', 'O'),
#   ('friday', 'B-tim'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('bombing', 'O'),
#   ('began', 'O'),
#   ('thursday', 'B-tim'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('barka', 'B-geo'),
#   ('valley', 'I-geo'),
#   ('region', 'O'),
#   ('near', 'O'),
#   ('the', 'O'),
#   ('town', 'O'),
#   ('of', 'O'),
#   ('tokar', 'B-geo'),
#   (',', 'O'),
#   ('120', 'O'),
#   ('kilometer', 'O'),
#   ('south', 'O'),
#   ('port', 'B-per'),
#   ('sudan', 'B-gpe'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('red', 'B-geo'),
#   ('sea', 'I-geo'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('french', 'B-gpe'),
#   ('news', 'O'),
#   ('agency', 'O'),
#   ('quote', 'O'),
#   ('a', 'O'),
#   ('rebel', 'O'),
#   ('spokesman', 'O'),
#   ('a', 'O'),
#   ('saying', 'O'),
#   ('many', 'O'),
#   ('civilian', 'O'),
#   ('have', 'O'),
#   ('been', 'O'),
#   ('injured', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('bomb', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('much', 'O'),
#   ('livestock', 'O'),
#   ('ha', 'O'),
#   ('been', 'O'),
#   ('killed', 'O'),
#   ('.', 'O')],
#  [('he', 'O'),
#   ('say', 'O'),
#   ('the', 'O'),
#   ('bombing', 'O'),
#   ('continue', 'O'),
#   ('friday', 'B-tim'),
#   ('.', 'O')],
#  [('there', 'O'),
#   ('ha', 'O'),
#   ('been', 'O'),
#   ('no', 'O'),
#   ('independent', 'O'),
#   ('verification', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('air', 'O'),
#   ('strike', 'O'),
#   ('.', 'O')],
#  [('fighting', 'O'),
#   ('broke', 'O'),
#   ('out', 'O'),
#   ('between', 'O'),
#   ('the', 'O'),
#   ('rebel', 'O'),
#   ('and', 'O'),
#   ('government', 'O'),
#   ('troop', 'O'),
#   ('near', 'O'),
#   ('tokar', 'B-geo'),
#   ('early', 'O'),
#   ('this', 'O'),
#   ('week', 'O'),
#   ('.', 'O')],
#  [('two', 'O'),
#   ('sudanese', 'B-gpe'),
#   ('rebel', 'O'),
#   ('faction', 'O'),
#   ('joined', 'O'),
#   ('force', 'O'),
#   ('in', 'O'),
#   ('february', 'B-tim'),
#   ('to', 'O'),
#   ('form', 'O'),
#   ('the', 'O'),
#   ('eastern', 'B-org'),
#   ('front', 'I-org'),
#   ('.', 'O')],
#  [('pope', 'O'),
#   ('benedict', 'B-per'),
#   ('xvi', 'I-per'),
#   ('ha', 'O'),
#   ('visited', 'O'),
#   ('the', 'O'),
#   ('italian', 'B-gpe'),
#   ('city', 'O'),
#   ('of', 'O'),
#   ("l'aquilla", 'B-geo'),
#   ('and', 'O'),
#   ('other', 'O'),
#   ('central', 'O'),
#   ('italian', 'B-gpe'),
#   ('locale', 'O'),
#   ('devastated', 'O'),
#   ('earlier', 'O'),
#   ('this', 'O'),
#   ('month', 'O'),
#   ('by', 'O'),
#   ('a', 'O'),
#   ('deadly', 'O'),
#   ('earthquake', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('pontiff', 'O'),
#   ('tuesday', 'B-tim'),
#   ('visited', 'O'),
#   ('several', 'O'),
#   ('site', 'O'),
#   ('in', 'O'),
#   ("l'aquilla", 'B-geo'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('medieval', 'O'),
#   ('walled', 'O'),
#   ('city', 'O'),
#   ('of', 'O'),
#   ('70,000', 'O'),
#   ('resident', 'O'),
#   ('.', 'O')],
#  [('his', 'O'),
#   ('stop', 'O'),
#   ('included', 'O'),
#   ('the', 'O'),
#   ('site', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('partially-collapsed', 'O'),
#   ('college', 'O'),
#   ('dormitory', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('ruin', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('13th', 'B-tim'),
#   ('century', 'I-tim'),
#   ('santa', 'B-geo'),
#   ('maria', 'I-geo'),
#   ('di', 'I-geo'),
#   ('collemaggio', 'I-geo'),
#   ('basilica', 'I-geo'),
#   ('.', 'O')],
#  [('speaking', 'O'),
#   ('to', 'O'),
#   ('survivor', 'O'),
#   (',', 'O'),
#   ('he', 'O'),
#   ('called', 'O'),
#   ('for', 'O'),
#   ('""""', 'O'),
#   ('an', 'O'),
#   ('examination', 'O'),
#   ('of', 'O'),
#   ('conscience', 'O'),
#   ('""""', 'O'),
#   ('by', 'O'),
#   ('builder', 'O'),
#   ('and', 'O'),
#   ('inspector', 'O'),
#   ('accused', 'O'),
#   ('of', 'O'),
#   ('shoddy', 'O'),
#   ('construction', 'O'),
#   ('practice', 'O'),
#   ('linked', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('collapse', 'O'),
#   ('of', 'O'),
#   ('numerous', 'O'),
#   ('building', 'O'),
#   ('.', 'O')],
#  [('benedict', 'B-per'),
#   ('earlier', 'O'),
#   ('visited', 'O'),
#   ('the', 'O'),
#   ('village', 'O'),
#   ('of', 'O'),
#   ('onna', 'B-geo'),
#   (',', 'O'),
#   ('where', 'O'),
#   ('40', 'O'),
#   ('of', 'O'),
#   ('300', 'O'),
#   ('resident', 'O'),
#   ('perished', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('6.4', 'O'),
#   ('magnitude', 'O'),
#   ('quake', 'O'),
#   ('on', 'O'),
#   ('april', 'B-tim'),
#   ('6', 'I-tim'),
#   ('reduced', 'O'),
#   ('large', 'O'),
#   ('section', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('abruzzo', 'B-geo'),
#   ('region', 'O'),
#   ('to', 'O'),
#   ('rubble', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('italian', 'B-gpe'),
#   ('government', 'O'),
#   ('ha', 'O'),
#   ('earmarked', 'O'),
#   ('more', 'O'),
#   ('than', 'O'),
#   ('$', 'O'),
#   ('10', 'O'),
#   ('billion', 'O'),
#   ('for', 'O'),
#   ('reconstruction', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('region', 'O'),
#   ('.', 'O')],
#  [('expert', 'O'),
#   ('say', 'O'),
#   ('it', 'O'),
#   ('will', 'O'),
#   ('take', 'O'),
#   ('about', 'O'),
#   ('$', 'O'),
#   ('16', 'O'),
#   ('billion', 'O'),
#   ('to', 'O'),
#   ('rebuild', 'O'),
#   ('the', 'O'),
#   ('area', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('top', 'O'),
#   ('u.s.', 'B-org'),
#   ('military', 'O'),
#   ('commander', 'O'),
#   ('in', 'O'),
#   ('afghanistan', 'B-geo'),
#   ('say', 'O'),
#   ('taleban', 'B-org'),
#   ('insurgent', 'O'),
#   ('could', 'O'),
#   ('stage', 'O'),
#   ('a', 'O'),
#   ('high-profile', 'O'),
#   ('attack', 'O'),
#   ('over', 'O'),
#   ('the', 'O'),
#   ('next', 'O'),
#   ('six', 'B-tim'),
#   ('to', 'I-tim'),
#   ('nine', 'I-tim'),
#   ('month', 'O'),
#   (',', 'O'),
#   ('despite', 'O'),
#   ('what', 'O'),
#   ('he', 'O'),
#   ('called', 'O'),
#   ('their', 'O'),
#   ('more', 'O'),
#   ('limited', 'O'),
#   ('""""', 'O'),
#   ('terrorist', 'O'),
#   ('capability', 'O'),
#   ('.', 'O'),
#   ('""""', 'O')],
#  [('lieutenant', 'B-per'),
#   ('general', 'I-per'),
#   ('david', 'I-per'),
#   ('barno', 'I-per'),
#   ('told', 'O'),
#   ('reporter', 'O'),
#   ('saturday', 'B-tim'),
#   ('the', 'O'),
#   ('taleban', 'B-org'),
#   ('fighter', 'O'),
#   ('are', 'O'),
#   ('becoming', 'O'),
#   ('more', 'O'),
#   ('desperate', 'O'),
#   ('to', 'O'),
#   ('""""', 'O'),
#   ('change', 'O'),
#   ('the', 'O'),
#   ('course', 'O'),
#   ('of', 'O'),
#   ('event', 'O'),
#   ('in', 'O'),
#   ('afghanistan', 'B-geo'),
#   ('.', 'O'),
#   ('""""', 'O')],
#  [('general', 'B-per'),
#   ('barno', 'I-per'),
#   ('said', 'O'),
#   ('he', 'O'),
#   ('expects', 'O'),
#   ('a', 'O'),
#   ('small', 'O'),
#   ('hard-core', 'O'),
#   ('remnant', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('taleban', 'B-org'),
#   ('to', 'O'),
#   ('continue', 'O'),
#   ('fighting', 'O'),
#   ('even', 'O'),
#   ('a', 'O'),
#   ('the', 'O'),
#   ('group', 'O'),
#   ("'s", 'O'),
#   ('military', 'O'),
#   ('strength', 'O'),
#   ('fade', 'O'),
#   ('away', 'O'),
#   ('.', 'O')],
#  [('afghanistan', 'B-gpe'),
#   ('is', 'O'),
#   ('scheduled', 'O'),
#   ('to', 'O'),
#   ('hold', 'O'),
#   ('parliamentary', 'O'),
#   ('election', 'O'),
#   ('on', 'O'),
#   ('september', 'B-tim'),
#   ('18', 'I-tim'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('little', 'O'),
#   ('le', 'O'),
#   ('than', 'O'),
#   ('one', 'B-tim'),
#   ('year', 'O'),
#   ('after', 'O'),
#   ('the', 'O'),
#   ('country', 'O'),
#   ("'s", 'O'),
#   ('first', 'O'),
#   ('direct', 'O'),
#   ('and', 'O'),
#   ('democratic', 'O'),
#   ('presidential', 'O'),
#   ('election', 'O'),
#   ('.', 'O')],
#  [('three', 'O'),
#   ('world', 'O'),
#   ('leader', 'O'),
#   ('who', 'O'),
#   ('had', 'O'),
#   ('key', 'O'),
#   ('role', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('reunification', 'O'),
#   ('of', 'O'),
#   ('germany', 'B-geo'),
#   ('gathered', 'O'),
#   ('saturday', 'B-tim'),
#   ('to', 'O'),
#   ('share', 'O'),
#   ('their', 'O'),
#   ('memory', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('collapse', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('berlin', 'B-org'),
#   ('wall', 'I-org'),
#   ('.', 'O')],
#  [('germany', 'B-geo'),
#   ("'s", 'O'),
#   ('ex-chancellor', 'O'),
#   ('helmut', 'B-per'),
#   ('kohl', 'I-per'),
#   (',', 'O'),
#   ('former', 'O'),
#   ('u.s.', 'B-geo'),
#   ('president', 'O'),
#   ('george', 'B-per'),
#   ('herbert', 'I-per'),
#   ('walker', 'I-per'),
#   ('bush', 'I-per'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('former', 'O'),
#   ('soviet', 'O'),
#   ('leader', 'O'),
#   ('mikhail', 'B-per'),
#   ('gorbachev', 'I-per'),
#   ('were', 'O'),
#   ('honored', 'O'),
#   ('at', 'O'),
#   ('a', 'O'),
#   ('gathering', 'O'),
#   ('in', 'O'),
#   ('berlin', 'B-geo'),
#   ('for', 'O'),
#   ('their', 'O'),
#   ('effort', 'O'),
#   ('in', 'O'),
#   ('reunifying', 'O'),
#   ('germany', 'B-geo'),
#   ('.', 'O')],
#  [('former', 'O'),
#   ('chancellor', 'B-per'),
#   ('kohl', 'I-per'),
#   ('now', 'O'),
#   ('speaks', 'O'),
#   ('with', 'O'),
#   ('difficulty', 'O'),
#   ('after', 'O'),
#   ('a', 'O'),
#   ('stroke', 'O'),
#   ('and', 'O'),
#   ('is', 'O'),
#   ('confined', 'O'),
#   ('to', 'O'),
#   ('a', 'O'),
#   ('wheelchair', 'O'),
#   ('.', 'O')],
#  [('he', 'O'),
#   ('said', 'O'),
#   ('that', 'O'),
#   ('although', 'O'),
#   ('germany', 'B-geo'),
#   ("'s", 'O'),
#   ('history', 'O'),
#   ('wa', 'O'),
#   ('not', 'O'),
#   ('always', 'O'),
#   ('proud', 'O'),
#   (',', 'O'),
#   ('german', 'B-gpe'),
#   ('should', 'O'),
#   ('be', 'O'),
#   ('proud', 'O'),
#   ('of', 'O'),
#   ('their', 'O'),
#   ('country', 'O'),
#   ("'s", 'O'),
#   ('reunification', 'O'),
#   ('.', 'O')],
#  [('at', 'O'),
#   ('the', 'O'),
#   ('close', 'O'),
#   ('of', 'O'),
#   ('world', 'O'),
#   ('war', 'O'),
#   ('ii', 'B-eve'),
#   (',', 'O'),
#   ('germany', 'B-geo'),
#   ('wa', 'O'),
#   ('divided', 'O'),
#   ('into', 'O'),
#   ('two', 'O'),
#   ('separate', 'O'),
#   ('country', 'O'),
#   ('governed', 'O'),
#   ('under', 'O'),
#   ('separate', 'O'),
#   ('ideology', 'O'),
#   ('of', 'O'),
#   ('democracy', 'O'),
#   ('and', 'O'),
#   ('communism', 'O'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('wall', 'O'),
#   ('wa', 'O'),
#   ('built', 'O'),
#   ('starting', 'O'),
#   ('in', 'O'),
#   ('1961', 'B-tim'),
#   ('and', 'O'),
#   ('came', 'O'),
#   ('to', 'O'),
#   ('symbolize', 'O'),
#   ('the', 'O'),
#   ('divide', 'O'),
#   ('between', 'O'),
#   ('the', 'O'),
#   ('so-called', 'O'),
#   ('iron', 'B-org'),
#   ('curtain', 'I-org'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('democratic', 'B-geo'),
#   ('west', 'I-geo'),
#   ('.', 'O')],
#  [('the', 'O'),
#   ('wall', 'O'),
#   ('wa', 'O'),
#   ('breached', 'O'),
#   ('on', 'O'),
#   ('november', 'B-tim'),
#   ('9', 'I-tim'),
#   (',', 'I-tim'),
#   ('1989', 'I-tim'),
#   ('a', 'O'),
#   ('a', 'O'),
#   ('worldwide', 'O'),
#   ('audience', 'O'),
#   ('watched', 'O'),
#   ('on', 'O'),
#   ('live', 'O'),
#   ('television', 'O'),
#   ('.', 'O')],
#  [('thousand', 'O'),
#   ('of', 'O'),
#   ('icelander', 'B-gpe'),
#   ('marked', 'O'),
#   ('the', 'O'),
#   ('90th', 'O'),
#   ('anniversary', 'O'),
#   ('of', 'O'),
#   ('sovereignty', 'O'),
#   ('from', 'O'),
#   ('denmark', 'B-org'),
#   ('monday', 'B-tim'),
#   ('by', 'O'),
#   ('demanding', 'O'),
#   ('the', 'O'),
#   ('government', 'O'),
#   ('resign', 'O'),
#   ('over', 'O'),
#   ('the', 'O'),
#   ('country', 'O'),
#   ("'s", 'O'),
#   ('economic', 'O'),
#   ('crisis', 'O'),
#   ('.', 'O')],
#  [('hundred', 'O'),
#   ('of', 'O'),
#   ('marcher', 'O'),
#   ('tried', 'O'),
#   ('to', 'O'),
#   ('storm', 'O'),
#   ('central', 'O'),
#   ('bank', 'O'),
#   ('headquarters', 'O'),
#   ('in', 'O'),
#   ('reykjavik', 'B-geo'),
#   ('.', 'O')],
#  [('they', 'O'),
#   ('left', 'O'),
#   ('after', 'O'),
#   ('a', 'O'),
#   ('tense', 'O'),
#   ('hour-long', 'O'),
#   ('standoff', 'O'),
#   ('with', 'O'),
#   ('riot', 'O'),
#   ('police', 'O'),
#   ('.', 'O')],
#  ...]

# %%
sentences[2022]
# Out:
# [('the', 'O'),
#  ('white', 'B-org'),
#  ('house', 'I-org'),
#  ('ha', 'O'),
#  ('expressed', 'O'),
#  ('doubt', 'O'),
#  ('about', 'O'),
#  ('a', 'O'),
#  ('russian', 'B-gpe'),
#  ('proposal', 'O'),
#  ('for', 'O'),
#  ('a', 'O'),
#  ('middle', 'B-geo'),
#  ('east', 'I-geo'),
#  ('peace', 'O'),
#  ('conference', 'O'),
#  (',', 'O'),
#  ('saying', 'O'),
#  ('diplomat', 'O'),
#  ('should', 'O'),
#  ('focus', 'O'),
#  ('on', 'O'),
#  ('israel', 'B-geo'),
#  ("'s", 'O'),
#  ('upcoming', 'O'),
#  ('gaza', 'B-geo'),
#  ('withdrawal', 'O'),
#  ('.', 'O')]

# %%
exsen = sentences[2022]
NEs=[]

def nextwords(i, sen):
    """
    Recursively seeks next I-tag word, 
    or calls nextfive() upon encoutering an O-tag word.
    """
    try:
        nextword, nexttag = sen[i+1][:]
        if nexttag[0]=='I':
            NE.append(nextword)
            nextwords(i+1, sen) #recursive
        elif nexttag[0]=='O':
            nextfive(i,sen)       
    except IndexError:
        pass

def nextfive(i, sen):
    """Tries appending the next 5 words unless out of index. """
    for c in range(1,6): #1~5
        try:
            nextword = sen[i+c][0]
            next5.append(nextword)
        except IndexError:
            pass
        
def prevfive(i, sen):
    """Tries appending the previous 5 words unless out of index. """
    for c in range(-5,0): # -5~-1
        try:
            if i+c>=0: #index must be positive to avoid indexing words from the end
                prevword = sen[i+c][0] 
                prev5.append(prevword)
        except IndexError:
            pass
        
for i in range(len(exsen)):
    word,tag = exsen[i][:]
    
    if tag[0]=='B':
        # Individual words of NE & its class
        NE=[word] # first word of NE
        NEclass=tag[2:]
        # Neighbouring 5 words
        prev5=[]
        next5=[]

        # Recursively look for ensuing words with I- tag, 
        # and 5 next words led by an O-tag word
        nextwords(i,exsen) 
        
        # Previous 5 words before the word with B- tag
        prevfive(i,exsen)
        
        
        NEs.append( (prev5, ' '.join(NE), NEclass, next5) )
        

NEs
# Out:
# [(['the'], 'white house', 'org', ['ha', 'expressed', 'doubt', 'about', 'a']),
#  (['ha', 'expressed', 'doubt', 'about', 'a'],
#   'russian',
#   'gpe',
#   ['proposal', 'for', 'a', 'middle', 'east']),
#  (['a', 'russian', 'proposal', 'for', 'a'],
#   'middle east',
#   'geo',
#   ['peace', 'conference', ',', 'saying', 'diplomat']),
#  (['saying', 'diplomat', 'should', 'focus', 'on'],
#   'israel',
#   'geo',
#   ["'s", 'upcoming', 'gaza', 'withdrawal', '.']),
#  (['focus', 'on', 'israel', "'s", 'upcoming'],
#   'gaza',
#   'geo',
#   ['withdrawal', '.'])]

# %%
instances = a2.create_instances(inputdata)

# %%
instances[20:40]
# Out:
# [Class: art Features: ['something', 'something', 'something', 'something', 'something', 'something'],
#  Class: eve Features: ['something', 'something', 'something', 'something', 'something', 'something', 'something'],
#  Class: eve Features: ['something', 'something', 'something', 'something', 'something'],
#  Class: per Features: ['something', 'something', 'something', 'something', 'something', 'something', 'something', 'something', 'something'],
#  Class: eve Features: ['something', 'something', 'something', 'something', 'something', 'something', 'something', 'something'],
#  Class: per Features: ['something', 'something'],
#  Class: art Features: ['something', 'something', 'something', 'something', 'something', 'something', 'something'],
#  Class: org Features: ['something', 'something', 'something', 'something', 'something', 'something', 'something', 'something'],
#  Class: geo Features: ['something', 'something'],
#  Class: eve Features: ['something', 'something', 'something', 'something', 'something', 'something', 'something', 'something', 'something'],
#  Class: eve Features: ['something', 'something'],
#  Class: org Features: ['something', 'something', 'something', 'something', 'something', 'something', 'something', 'something', 'something'],
#  Class: art Features: ['something'],
#  Class: geo Features: ['something', 'something', 'something', 'something', 'something', 'something', 'something', 'something', 'something'],
#  Class: gpe Features: ['something', 'something', 'something', 'something', 'something'],
#  Class: org Features: ['something', 'something', 'something', 'something', 'something', 'something', 'something', 'something'],
#  Class: gpe Features: ['something', 'something'],
#  Class: geo Features: ['something', 'something', 'something', 'something', 'something', 'something', 'something', 'something', 'something'],
#  Class: eve Features: ['something', 'something'],
#  Class: per Features: ['something', 'something', 'something']]

# %% [markdown]
# ## Part 3 - Creating the table and splitting (10 points)
#
# Here you're going to write the functions that create a data table with "document" vectors representing each instance and split the table into training and testing sets and random with an 80%/20% train/test split.

# %%
bigdf = a2.create_table(instances)
bigdf[20:40]
# Out:
#    class         0         1         2         3         4         5  \
# 20   org  0.926686  0.131793  0.232024  0.513098  0.578857  0.578128
# 21   gpe  0.635842  0.448393  0.136491  0.266268  0.103289  0.922494
# 22   geo  0.146184  0.605401  0.983006  0.652167  0.922579  0.384944
# 23   per  0.513166  0.958203  0.248412  0.460424  0.673046  0.848564
# 24   eve  0.891877  0.368867  0.661577  0.862164  0.126615  0.390618
# 25   nat  0.492072  0.503133  0.262815  0.389307  0.923006  0.455099
# 26   geo  0.824472  0.254229  0.028456  0.806945  0.489343  0.617794
# 27   geo  0.636093  0.719849  0.501325  0.814009  0.589548  0.432188
# 28   geo  0.453895  0.734696  0.181448  0.342434  0.566252  0.974137
# 29   eve  0.036027  0.990525  0.642186  0.032207  0.930533  0.259836
# 30   org  0.717040  0.288531  0.512176  0.568055  0.607985  0.524223
# 31   art  0.445148  0.405794  0.306550  0.293953  0.962546  0.245468
# 32   org  0.887282  0.469393  0.811869  0.730662  0.438265  0.745521
# 33   per  0.913957  0.178842  0.054457  0.635528  0.987703  0.399274
# 34   gpe  0.809766  0.105967  0.084732  0.579953  0.334400  0.670686
# 35   gpe  0.612338  0.965475  0.176543  0.024853  0.866228  0.899183
# 36   gpe  0.588255  0.169957  0.395905  0.751573  0.767775  0.917486
# 37   art  0.119427  0.212011  0.392778  0.909375  0.316318  0.722398
# 38   art  0.053910  0.751293  0.477019  0.299522  0.373720  0.436438
# 39   org  0.069601  0.244223  0.575771  0.816787  0.149430  0.409474
#
#            6         7         8  ...      2990      2991      2992      2993  \
# 20  0.965798  0.662039  0.131178  ...  0.613675  0.854569  0.843708  0.707635
# 21  0.695063  0.184550  0.659619  ...  0.272714  0.870007  0.455337  0.402589
# 22  0.259160  0.962548  0.909432  ...  0.518583  0.755413  0.101440  0.382964
# 23  0.677467  0.733854  0.416897  ...  0.077452  0.520626  0.882582  0.455886
# 24  0.653392  0.536814  0.998781  ...  0.216609  0.129308  0.922818  0.139315
# 25  0.339930  0.081616  0.400278  ...  0.321377  0.636289  0.661980  0.678692
# 26  0.310531  0.057363  0.687665  ...  0.146641  0.263967  0.101155  0.799974
# 27  0.158039  0.172840  0.845824  ...  0.358586  0.391383  0.871346  0.284972
# 28  0.708312  0.902479  0.411599  ...  0.498407  0.984741  0.282428  0.933634
# 29  0.571934  0.576637  0.761992  ...  0.634440  0.491855  0.733793  0.362658
# 30  0.118052  0.190833  0.294069  ...  0.186992  0.082216  0.665196  0.793373
# 31  0.377708  0.672188  0.405918  ...  0.716963  0.740168  0.694976  0.836962
# 32  0.950493  0.217749  0.293489  ...  0.828434  0.351464  0.205006  0.453552
# 33  0.631961  0.242069  0.896041  ...  0.148411  0.167355  0.200967  0.624000
# 34  0.881944  0.496065  0.129953  ...  0.879677  0.938372  0.890464  0.620987
# 35  0.130708  0.442992  0.988826  ...  0.770342  0.433451  0.499915  0.223756
# 36  0.932079  0.005400  0.687693  ...  0.605824  0.796215  0.102635  0.005998
# 37  0.801454  0.015185  0.241311  ...  0.748659  0.712728  0.900815  0.142658
# 38  0.855255  0.775980  0.724469  ...  0.174355  0.596385  0.357913  0.417407
# 39  0.861800  0.191908  0.103720  ...  0.563524  0.450155  0.481168  0.145390
#
#         2994      2995      2996      2997      2998      2999
# 20  0.843538  0.315971  0.070532  0.979287  0.761983  0.025728
# 21  0.884686  0.155075  0.660957  0.911090  0.683966  0.687450
# 22  0.235280  0.199173  0.944729  0.280266  0.480315  0.447179
# 23  0.642164  0.803096  0.234382  0.163650  0.445362  0.905514
# 24  0.325470  0.059960  0.029538  0.497251  0.015272  0.332287
# 25  0.639274  0.066781  0.354363  0.772618  0.169012  0.515791
# 26  0.448125  0.114646  0.535949  0.111716  0.111388  0.270271
# 27  0.519413  0.378377  0.822762  0.459148  0.863512  0.488491
# 28  0.776156  0.644804  0.842637  0.166234  0.431148  0.145238
# 29  0.179981  0.014313  0.076464  0.221847  0.620260  0.823728
# 30  0.202493  0.631092  0.895222  0.207644  0.957546  0.745790
# 31  0.456911  0.731720  0.082914  0.565920  0.798188  0.990969
# 32  0.418416  0.226848  0.645203  0.654614  0.993050  0.146965
# 33  0.141853  0.316686  0.598219  0.540169  0.815406  0.168349
# 34  0.849452  0.288651  0.168172  0.262945  0.099899  0.954488
# 35  0.543903  0.228819  0.116941  0.374607  0.618909  0.566660
# 36  0.525224  0.494360  0.882414  0.142315  0.602747  0.927233
# 37  0.265593  0.146565  0.646247  0.213198  0.423884  0.325988
# 38  0.115948  0.849665  0.002414  0.207729  0.275453  0.810699
# 39  0.177777  0.152108  0.124387  0.596243  0.032301  0.218217
#
# [20 rows x 3001 columns]

# %%
train_X, train_y, test_X, test_y = a2.ttsplit(bigdf)

# X and y mean feature matrix and class respectively.
train_X, train_y, test_X, test_y
# Out:
# (array([[0.70484028, 0.77705168, 0.90626172, ..., 0.42905333, 0.24064187,
#          0.13284756],
#         [0.04123746, 0.75263423, 0.82603426, ..., 0.19251307, 0.38836701,
#          0.79849862],
#         [0.97321444, 0.05596415, 0.36369891, ..., 0.90343845, 0.76148659,
#          0.83836349],
#         ...,
#         [0.49099448, 0.80228978, 0.91855497, ..., 0.22532328, 0.71194009,
#          0.19050029],
#         [0.56310329, 0.72478209, 0.40060363, ..., 0.59340161, 0.47651113,
#          0.85589867],
#         [0.84887086, 0.70425809, 0.64863831, ..., 0.15375111, 0.52449518,
#          0.92194385]]),
#  0     tim
#  1     nat
#  2     per
#  3     gpe
#  4     nat
#       ...
#  75    geo
#  76    tim
#  77    per
#  78    geo
#  79    art
#  Name: class, Length: 80, dtype: object,
#  array([[0.41216972, 0.4682734 , 0.57299347, ..., 0.9179704 , 0.08185916,
#          0.00494053],
#         [0.5593475 , 0.85286236, 0.87651353, ..., 0.08948916, 0.68671652,
#          0.57111886],
#         [0.95088606, 0.89561296, 0.50951007, ..., 0.20147049, 0.85360502,
#          0.1587294 ],
#         ...,
#         [0.67432036, 0.81857762, 0.00515241, ..., 0.4662484 , 0.85502844,
#          0.53242659],
#         [0.72484586, 0.89553018, 0.5945336 , ..., 0.9987756 , 0.32719275,
#          0.89766093],
#         [0.85156356, 0.64964995, 0.55811154, ..., 0.32370817, 0.15525834,
#          0.55553401]]),
#  0     per
#  1     eve
#  2     per
#  3     tim
#  4     art
#  5     nat
#  6     geo
#  7     org
#  8     geo
#  9     org
#  10    eve
#  11    per
#  12    gpe
#  13    nat
#  14    eve
#  15    per
#  16    gpe
#  17    per
#  18    gpe
#  19    art
#  Name: class, dtype: object)

# %%
len(test_y) / (len(test_y) + len(train_y))
# Out:
# 0.2

# %%
len(test_X) / (len(test_X) + len(train_X))
# Out:
# 0.2

# %%
test_y[0]
# Out:
# 'per'

# %% [markdown]
# ## Part 4 - Training the model (0 points)

# %% [markdown]
# This part you won't do yourself.

# %%
model = LinearSVC()
model.fit(train_X, train_y)
train_predictions = model.predict(train_X)
test_predictions = model.predict(test_X)

# %%
train_predictions
# Out:
# array(['tim', 'nat', 'per', 'gpe', 'nat', 'art', 'gpe', 'gpe', 'per',
#        'gpe', 'art', 'gpe', 'org', 'gpe', 'nat', 'geo', 'nat', 'geo',
#        'nat', 'eve', 'org', 'geo', 'geo', 'org', 'geo', 'art', 'gpe',
#        'nat', 'gpe', 'eve', 'gpe', 'gpe', 'org', 'per', 'art', 'geo',
#        'eve', 'tim', 'gpe', 'geo', 'per', 'geo', 'per', 'per', 'art',
#        'gpe', 'gpe', 'per', 'eve', 'nat', 'tim', 'org', 'art', 'gpe',
#        'geo', 'art', 'art', 'geo', 'gpe', 'nat', 'eve', 'eve', 'eve',
#        'geo', 'nat', 'org', 'gpe', 'art', 'nat', 'art', 'nat', 'tim',
#        'org', 'nat', 'org', 'geo', 'tim', 'per', 'geo', 'art'],
#       dtype=object)

# %%
train_y
# Out:
# 0     tim
# 1     nat
# 2     per
# 3     gpe
# 4     nat
#      ...
# 75    geo
# 76    tim
# 77    per
# 78    geo
# 79    art
# Name: class, Length: 80, dtype: object

# %%
test_predictions
# Out:
# array(['gpe', 'geo', 'gpe', 'nat', 'per', 'gpe', 'gpe', 'gpe', 'nat',
#        'eve', 'org', 'geo', 'gpe', 'nat', 'gpe', 'nat', 'geo', 'gpe',
#        'gpe', 'gpe'], dtype=object)

# %%
test_y
# Out:
# 0     per
# 1     eve
# 2     per
# 3     tim
# 4     art
# 5     nat
# 6     geo
# 7     org
# 8     geo
# 9     org
# 10    eve
# 11    per
# 12    gpe
# 13    nat
# 14    eve
# 15    per
# 16    gpe
# 17    per
# 18    gpe
# 19    art
# Name: class, dtype: object

# %% [markdown]
# ## Part 5 - Evaluation (5 points)

# %% [markdown]
# Investigate for yourself what a "confusion matrix".  Then implement a function that takes the data and produces a confusion matrix in any readable form that allows us to compare the performance of the model by class.

# %%
a2.confusion_matrix(test_y, test_predictions)
# Out:
# I'm confusing.
# "I'm confused."

# %%
a2.confusion_matrix(train_y, train_predictions)
# Out:
# I'm confusing.
# "I'm confused."

# %% [markdown]
# Examine the matrix and describe your observations in README.md.  In particular, what do you notice about the predictions on the training data compared to those on the test data.

# %% [markdown]
# ## Bonus Part A - Error analysis (2 points)

# %% [markdown]
# Look at the weakest-performing classes in the confusion matrix (or any, if they all perform poorly to the same extent).  Find some examples in the test data on which the classifier classified incorrectly for those classes.  What do you think is the reason why those are hard?  Consider linguistic factors and statistical factors, if applicable.  Write your answer in README.md.

# %% [markdown]
# ## Bonus Part B - Expanding the feature space (7 points)

# %% [markdown]
# Run the entire process above, but incorporate part-of-speech tag information into the feature vectors.  It's your choice as to how to do this, but document it in README.md.  Your new process should run from the single call below:

# %%
a2.bonusb('GMB_dataset.txt')
